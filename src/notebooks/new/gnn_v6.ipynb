# %%
#!/usr/bin/env python3
"""
GNN for Task-to-Platform Placement Prediction
Train a Graph Isomorphism Network (GIN) to predict optimal task placements.
"""

import os
import json
import random
import pandas as pd
import numpy as np
from pathlib import Path
from typing import Any, Dict, List, Tuple
import warnings
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.utils import to_undirected
from torch_geometric.nn.models import GIN
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from joblib import Parallel, delayed
import wandb


random.seed(42); 
np.random.seed(42); 
torch.manual_seed(42)
torch.cuda.manual_seed_all(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# Configuration
BASE_DIR = Path("/root/projects/my-herosim/simulation_data/artifacts/run10_all/gnn_datasets")
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyperparameters intended for grid search
# 16, 32, 64
EMBEDDING_DIM = 32

# 32, 64, 128
HIDDEN_DIM = 32

# 0.005, 0.001, 0.0005 
LEARNING_RATE = 0.001

# 16, 32
BATCH_SIZE = 16

# 3, 5
NUM_GIN_LAYERS = 3

# don't grid search
WEIGHT_DECAY = 1e-3
EPOCHS = 100

# %%
# ============================================================================
# DATA LOADING (reuse extraction logic)
# ============================================================================

def extract_dataset_to_dataframes(optimal_result_path: Path) -> Dict[str, pd.DataFrame]:
    """Extract a single optimal_result.json into DataFrames."""
    with open(optimal_result_path, "r") as f:
        result = json.load(f)
    
    dataset_id = optimal_result_path.parent.name
    infra_nodes = result.get("config", {}).get("infrastructure", {}).get("nodes", [])
    stats = result.get("stats", {})
    task_results = stats.get("taskResults", [])
    placement_plan = result.get("sample", {}).get("placement_plan", {})
    
    # NODES
    nodes_data = []
    for i, node in enumerate(infra_nodes):
        node_name = node.get("node_name", f"node_{i}")
        platforms = node.get("platforms", [])
        network_map = node.get("network_map", {})
        
        nodes_data.append({
            'node_id': i,
            'node_name': node_name,
            'node_type': node.get("type", "unknown"),
            'is_client': node_name.startswith('client_node'),
            'network_map': network_map
        })
    
    df_nodes = pd.DataFrame(nodes_data)
    
    # TASKS
    tasks_data = []
    for task_result in task_results:
        task_id = task_result.get("taskId")
        placement = placement_plan.get(str(task_id), [None, None])
        
        if isinstance(placement, list) and len(placement) >= 2:
            opt_node_id, opt_platform_id = placement[0], placement[1]
        else:
            opt_node_id, opt_platform_id = None, None
        
        tasks_data.append({
            'task_id': task_id,
            'task_type': task_result.get("taskType", {}).get("name", "unknown"),
            'source_node': task_result.get("sourceNode", ""),
            'optimal_node_id': opt_node_id,
            'optimal_platform_id': opt_platform_id,
            'elapsed_time': task_result.get("elapsedTime", 0)
        })
    
    df_tasks = pd.DataFrame(tasks_data)
    
    # PLATFORMS
    platforms_data = []
    node_results = stats.get("nodeResults", [])
    system_state = stats.get("systemStateResults", [{}])[-1] if stats.get("systemStateResults") else {}
    replicas_by_task = system_state.get("replicas", {})
    
    for node_result in node_results:
        node_id = node_result.get("nodeId")
        node_name = infra_nodes[node_id].get("node_name") if node_id < len(infra_nodes) else f"node_{node_id}"
        
        for plat_result in node_result.get("platformResults", []):
            plat_id = plat_result.get("platformId")
            plat_type = plat_result.get("platformType", {}).get("shortName", "unknown")
            
            # Check replica state
            has_dnn1_replica = False
            has_dnn2_replica = False
            
            for task_type, replica_list in replicas_by_task.items():
                if isinstance(replica_list, list):
                    for replica in replica_list:
                        if isinstance(replica, list) and len(replica) >= 2:
                            if replica[0] == node_name and replica[1] == plat_id:
                                if task_type == "dnn1":
                                    has_dnn1_replica = True
                                elif task_type == "dnn2":
                                    has_dnn2_replica = True
            
            platforms_data.append({
                'platform_id': plat_id,
                'node_id': node_id,
                'node_name': node_name,
                'platform_type': plat_type,
                'has_dnn1_replica': has_dnn1_replica, # has_dnn1_replica: bool
                'has_dnn2_replica': has_dnn2_replica # has_dnn2_replica: bool
            })
    
    df_platforms = pd.DataFrame(platforms_data)
    
    # METRICS
    best_json_path = optimal_result_path.parent / "best.json"
    best_rtt = None
    if best_json_path.exists():
        with open(best_json_path, "r") as f:
            best_rtt = json.load(f).get("rtt")
    if best_rtt is None:
        best_rtt = sum(tr.get("elapsedTime", 0) for tr in task_results)
    
    df_metrics = pd.DataFrame([{'dataset_id': dataset_id, 'total_rtt': best_rtt}])
    
    return {
        'nodes': df_nodes,
        'tasks': df_tasks,
        'platforms': df_platforms,
        'metrics': df_metrics
    }

def load_placement_summaries(dataset_dir: Path) -> List[Dict]:
    """Load all placement summaries from placements/ folder."""
    placements_dir = dataset_dir / "placements"
    if not placements_dir.exists():
        print(f"  [DEBUG] No placements/ directory found in {dataset_dir.name}")
        return []
    
    summary_files = list(placements_dir.glob("placement_summary_*.json"))
    if len(summary_files) == 0:
        print(f"  [DEBUG] No placement_summary_*.json files found in {dataset_dir.name}/placements/")
        return []
    
    summaries = []
    for summary_file in summary_files:
        try:
            with open(summary_file, "r") as f:
                summary = json.load(f)
                # Validate summary structure
                if 'placement_plan' not in summary:
                    print(f"  [WARNING] {summary_file.name} missing 'placement_plan' key")
                if 'rtt' not in summary:
                    print(f"  [WARNING] {summary_file.name} missing 'rtt' key")
                summaries.append(summary)
        except Exception as e:
            print(f"  Warning: Failed to load {summary_file.name}: {e}")

    if len(summaries) == 0:
        print(f"  [ERROR] Loaded {len(summaries)} placement summaries from {dataset_dir.name}")
    return summaries

def load_all_datasets(base_dir: Path) -> Dict[str, Dict[str, pd.DataFrame]]:
    """Load all datasets from gnn_datasets directory, including placement summaries."""
    all_datasets = {}
    dataset_dirs = sorted(base_dir.glob("ds_*"))
    
    print(f"Loading {len(dataset_dirs)} datasets...")
    total_summaries = 0
    datasets_with_summaries = 0
    
    for dataset_dir in dataset_dirs:
        optimal_result_path = dataset_dir / "optimal_result.json"
        if not optimal_result_path.exists():
            continue
        
        try:
            dataframes = extract_dataset_to_dataframes(optimal_result_path)
            # Load placement summaries
            placement_summaries = load_placement_summaries(dataset_dir)
            
            if len(placement_summaries) > 0:
                datasets_with_summaries += 1
                total_summaries += len(placement_summaries)
            
            # Store both dataframes and placement summaries
            all_datasets[dataset_dir.name] = {
                **dataframes,
                '_placement_summaries': placement_summaries,
                'dataset_dir': dataset_dir
            }
        except Exception as e:
            print(f"  Error loading {dataset_dir.name}: {e}")
    
    print(f"Loaded {len(all_datasets)} datasets successfully")
    print(f"[DEBUG] Placement summaries: {total_summaries} total across {datasets_with_summaries}/{len(all_datasets)} datasets\n")
    return all_datasets

# %%
# ============================================================================
# GRAPH CONSTRUCTION (sped up; same functionality)
# ============================================================================

# Hardcoded compatibility: task types -> allowed platform types
TASK_PLATFORM_COMPATIBILITY = {
    'dnn1': ['rpiCpu', 'xavierGpu', 'xavierCpu'],
    'dnn2': ['rpiCpu', 'xavierGpu', 'xavierCpu']
}

def build_graph(df_nodes, df_tasks, df_platforms) -> Data:
    """
    Build a bipartite graph with tasks and platforms as nodes.
    Edges connect tasks to feasible platforms based on network connectivity AND compatibility.

      - Task features: one-hot(task_type in ['dnn1','dnn2']) + normalized source node index
      - Platform features: one-hot(platform_type in ['rpiCpu','xavierCpu','xavierGpu','xavierDla','pynqFpga'])
                           + has_dnn1_replica + has_dnn2_replica
      - Edges: task -> compatible platforms that are:
               1) Network feasible (source node + its network neighbors)
               2) Compatible platform type (from TASK_PLATFORM_COMPATIBILITY)
               3) Have replica for the task type (has_dnn1_replica for dnn1, has_dnn2_replica for dnn2)
      - Reverse edges are added (undirected graph for GIN)
      - Labels y: for each task, index of optimal platform within *its own* compatible list; -1 if no compatible platforms
    """

    # ---------------------------------------------
    # Basic sizes / offsets
    # ---------------------------------------------
    n_tasks = len(df_tasks)
    n_platforms = len(df_platforms)
    task_offset = 0
    platform_offset = n_tasks

    # ---------------------------------------------
    # Precompute lookups (no per-row DataFrame scans)
    # ---------------------------------------------
    # node_name -> FIRST matching *index label* in df_nodes (preserves original behavior)
    # If names are unique, this is just a simple mapping; if not, we take the first.
    # (Using groupby-first avoids .loc in a loop.)
    first_idx_per_name = (
        df_nodes.reset_index()[['index', 'node_name']]
        .groupby('node_name', as_index=True)['index']
        .first()
        .to_dict()
    )

    # platform_id -> positional index (0..P-1)
    plat_pos_by_id = {row.platform_id: i for i, row in enumerate(df_platforms.itertuples(index=False))}

    # node_name -> list of platform *positions* on that node
    plats_by_node = {}
    node_names_arr = df_platforms['node_name'].to_numpy()
    for pos, name in enumerate(node_names_arr):
        plats_by_node.setdefault(name, []).append(pos)

    # node_name -> network_map dict (fast direct access)
    network_map_by_node = {row.node_name: row.network_map for row in df_nodes.itertuples(index=False)}

    # ---------------------------------------------
    # TASK FEATURES (vectorized)
    # [task_type_onehot (2), source_node_id_norm (1)]
    # ---------------------------------------------
    task_types_vocab = np.array(['dnn1', 'dnn2'])
    task_type_arr = df_tasks['task_type'].to_numpy()
    task_onehot = (task_type_arr[:, None] == task_types_vocab[None, :]).astype(float)

    src_names = df_tasks['source_node'].to_numpy()
    # map to first index label; default 0 if missing
    src_idx = np.fromiter((first_idx_per_name.get(n, 0) for n in src_names),
                          dtype=np.float64, count=n_tasks)
    src_norm = (src_idx / max(len(df_nodes), 1)).reshape(-1, 1)

    task_features = np.concatenate([task_onehot, src_norm], axis=1)
    task_features_tensor = torch.from_numpy(task_features).to(torch.float32)

    # ---------------------------------------------
    # PLATFORM FEATURES (vectorized)
    # [platform_type_onehot (5), has_dnn1, has_dnn2]
    # ---------------------------------------------

    platform_types_vocab = np.array(['rpiCpu','xavierCpu','xavierGpu','xavierDla','pynqFpga'])
    plat_type_arr = df_platforms['platform_type'].to_numpy()
    plat_onehot = (plat_type_arr[:, None] == platform_types_vocab[None, :]).astype(float)

    has_dnn1_arr = df_platforms['has_dnn1_replica'].to_numpy(dtype=bool)
    has_dnn2_arr = df_platforms['has_dnn2_replica'].to_numpy(dtype=bool)
    
    # Keep float versions for features
    has_dnn1 = has_dnn1_arr.astype(float).reshape(-1, 1)
    has_dnn2 = has_dnn2_arr.astype(float).reshape(-1, 1)

    platform_features = np.concatenate([plat_onehot, has_dnn1, has_dnn2], axis=1)
    platform_features_tensor = torch.from_numpy(platform_features).to(torch.float32)

    # ---------------------------------------------
    # Cache feasible platforms per source node (avoid repeated filtering)
    # ---------------------------------------------
    feasible_plats_cache = {}
    def feasible_platform_positions(src_node_name: str) -> np.ndarray:
        """Get network-feasible platform positions (source node + network neighbors)."""
        hit = feasible_plats_cache.get(src_node_name)
        if hit is not None:
            return hit
        nm = network_map_by_node.get(src_node_name, {})
        feasible_nodes = [src_node_name, *nm.keys()] if isinstance(nm, dict) else [src_node_name]
        out = []
        for node in feasible_nodes:
            out.extend(plats_by_node.get(node, ()))
        arr = np.fromiter(out, dtype=np.int64, count=len(out)) if out else np.empty(0, dtype=np.int64)
        feasible_plats_cache[src_node_name] = arr
        return arr

    # ---------------------------------------------
    # Compatibility filtering (vectorized)
    # ---------------------------------------------
    # Pre-compute allowed platform types as numpy arrays for vectorized operations
    allowed_types_dnn1 = np.array(TASK_PLATFORM_COMPATIBILITY.get('dnn1', []))
    allowed_types_dnn2 = np.array(TASK_PLATFORM_COMPATIBILITY.get('dnn2', []))
    
    # Pre-compute platform type compatibility masks (boolean arrays) using vectorized operations
    plat_type_compat_dnn1 = np.isin(plat_type_arr, allowed_types_dnn1)
    plat_type_compat_dnn2 = np.isin(plat_type_arr, allowed_types_dnn2)
    
    def filter_compatible_platforms(
        network_feasible_plats: np.ndarray,
        task_type: str
    ) -> np.ndarray:
        """
        Filter platforms by compatibility rules (vectorized):
        1. Platform type must be in TASK_PLATFORM_COMPATIBILITY[task_type]
        2. Platform must have the appropriate replica (has_dnn1_replica for dnn1, has_dnn2_replica for dnn2)
        
        Args:
            network_feasible_plats: Array of platform positions (0..P-1) that are network-feasible
            task_type: Task type ('dnn1' or 'dnn2')
            
        Returns:
            Array of compatible platform positions
        """
        if network_feasible_plats.size == 0:
            return network_feasible_plats
        
        # Get pre-computed compatibility masks
        if task_type == 'dnn1':
            type_mask = plat_type_compat_dnn1
            replica_mask = has_dnn1_arr
        elif task_type == 'dnn2':
            type_mask = plat_type_compat_dnn2
            replica_mask = has_dnn2_arr
        else:
            # Unknown task type -> no compatible platforms
            return np.empty(0, dtype=np.int64)
        
        # Vectorized filtering: platform type compatible AND has replica
        # Apply mask to the network-feasible platforms only
        compatible_mask = type_mask[network_feasible_plats] & replica_mask[network_feasible_plats]
        
        return network_feasible_plats[compatible_mask]

    # ---------------------------------------------
    # EDGES + LABELS
    # ---------------------------------------------
    edge_src, edge_dst = [], []
    y_list = []

    optimal_platform_ids = df_tasks['optimal_platform_id'].to_numpy()
    task_types_arr = df_tasks['task_type'].to_numpy()

    for t_pos, (src_name, opt_pid, task_type) in enumerate(zip(src_names, optimal_platform_ids, task_types_arr)):
        # Step 1: Get network-feasible platforms
        network_feas_plats = feasible_platform_positions(src_name)  # platform positions (0..P-1)
        
        # Step 2: Filter by compatibility (platform type + replica) - vectorized
        compat_plats = filter_compatible_platforms(network_feas_plats, task_type)
        
        if compat_plats.size:
            task_node_idx = task_offset + t_pos
            # Edges: task -> (n_tasks + platform_pos)
            edge_src.extend([task_node_idx] * compat_plats.size)
            edge_dst.extend((platform_offset + compat_plats).tolist())

            # Label: index of optimal platform within this task's COMPATIBLE list (-1 if not found)
            opt_pos = plat_pos_by_id.get(opt_pid, None)
            if opt_pos is None:
                # Optimal platform not in platform list -> invalid label
                y_list.append(-1)
            else:
                # Check if optimal platform is in the compatible list
                matches = np.nonzero(compat_plats == opt_pos)[0]
                if matches.size:
                    y_list.append(int(matches[0]))  # Index within compatible platforms
                else:
                    # Optimal platform exists but not in compatible set -> invalid label
                    y_list.append(-1)
        else:
            # No compatible platforms → no edges for this task; invalid label
            y_list.append(-1)

    # Stack edges
    if edge_src:
        edge_index = torch.tensor([edge_src, edge_dst], dtype=torch.long)
        # Add reverse edges: make undirected for GIN message passing
        num_nodes = n_tasks + n_platforms
        edge_index = to_undirected(edge_index, num_nodes=num_nodes)
    else:
        edge_index = torch.empty((2, 0), dtype=torch.long)

    y = torch.tensor(y_list, dtype=torch.long)

    # ---------------------------------------------
    # Create PyG Data
    # ---------------------------------------------
    data = Data(
        edge_index=edge_index,
        y=y,
        n_tasks=n_tasks,
        n_platforms=n_platforms,
        task_features=task_features_tensor,             # dim=3
        platform_features=platform_features_tensor,     # dim=7
    )
    # Store platform position mapping as private attribute (PyG will skip during batching)
    data._plat_pos_by_id = plat_pos_by_id

    return data

# %%
# ============================================================================
# GNN MODEL
# ============================================================================

class TaskEncoder(nn.Module):
    """2-layer MLP encoder for task features with LayerNorm for training stability."""
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.norm1 = nn.LayerNorm(hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.norm1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x


class PlatformEncoder(nn.Module):
    """2-layer MLP encoder for platform features with LayerNorm for training stability."""
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.norm1 = nn.LayerNorm(hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.norm1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x



class EdgeScorer(nn.Module):
    """2-layer MLP to score task-platform edges."""
    def __init__(self, embedding_dim, hidden_dim):
        super().__init__()
        # Input: concatenation of task and platform embeddings
        self.fc1 = nn.Linear(2 * embedding_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 1)
    
    def forward(self, e_task, e_platform):
        # Concatenate task and platform embeddings
        # e_task: (E, D) or (1, D)
        # e_platform: (E, D) or (1, D)
        x = torch.cat([e_task, e_platform], dim=-1)  # (E, 2D)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)                              # (E, 1)
        return x.squeeze(-1)                         # (E,)

class TaskPlacementGNN(nn.Module):
    """
    1. Encode task and platform features separately
    2. GIN to produce node embeddings
    3. Edge MLP to score task-platform compatibility
    4. Masked softmax to predict placement probabilities
    """
    def __init__(self, task_feature_dim, platform_feature_dim, embedding_dim=64, hidden_dim=128, num_layers=3):
        super().__init__()
        
        self.embedding_dim = embedding_dim
        
        # Separate encoders for tasks and platforms
        self.task_encoder = TaskEncoder(task_feature_dim, hidden_dim, embedding_dim)
        self.platform_encoder = PlatformEncoder(platform_feature_dim, hidden_dim, embedding_dim)
        
        # GIN model for message passing
        self.gin = GIN(
            in_channels=embedding_dim,
            hidden_channels=hidden_dim,
            num_layers=num_layers,
            out_channels=embedding_dim
        )
        
        # Edge scoring MLP
        self.edge_scorer = EdgeScorer(embedding_dim, hidden_dim)

    def forward(self, data):
        n_tasks = data.n_tasks
        n_platforms = data.n_platforms

        # 1) Encode features
        task_embeddings = self.task_encoder(data.task_features)        # (T, D)
        platform_embeddings = self.platform_encoder(data.platform_features)  # (P, D)

        # 2) Message passing on concatenated nodes
        x = torch.cat([task_embeddings, platform_embeddings], dim=0)   # (T+P, D)
        x = self.gin(x, data.edge_index)

        task_emb = x[:n_tasks]        # (T, D)
        platform_emb = x[n_tasks:]    # (P, D)

        # 3) Score all edges in one shot
        ei = data.edge_index                                             # (2, E)
        if ei.numel() == 0:
            # No edges in this graph: return empty logits per task
            return [torch.empty(0, device=x.device) for _ in range(n_tasks)]

        ti = ei[0]                                                        # (E,) task indices [0..T-1]
        pj = ei[1] - n_tasks                                              # (E,) platform indices [0..P-1]
        valid = (pj >= 0) & (pj < n_platforms)
        ti = ti[valid]
        pj = pj[valid]
        if ti.numel() == 0:
            return [torch.empty(0, device=x.device) for _ in range(n_tasks)]

        e_task = task_emb[ti]                # (E_valid, D)
        e_platform = platform_emb[pj]        # (E_valid, D)
        edge_scores = self.edge_scorer(e_task, e_platform)   # (E_valid,)

        # 4) Split scores per task
        logits_per_task = []
        for t in range(n_tasks):
            mask_t = (ti == t)
            logits_t = edge_scores[mask_t]   # (K_t,)
            logits_per_task.append(logits_t)

        return logits_per_task

# %%
# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def loss_original_ce(logits_per_task, data, device):
    """
    Original cross-entropy loss with one-hot labels (optimal placement).
    L_t = -log(π_t,p*(t))
    """
    loss_total = torch.zeros(1, device=device)
    valid_tasks = 0
    
    for task_idx, logits_t in enumerate(logits_per_task):
        if logits_t.numel() == 0:
            continue
        
        logits = logits_t.unsqueeze(0)  # (1, K)
        target = data.y[task_idx].long()
        if target.ndim == 0:
            target = target.unsqueeze(0)
        
        if target.item() < 0 or target.item() >= logits.size(1):
            continue
        
        loss_total = loss_total + F.cross_entropy(logits, target)
        valid_tasks += 1
    
    if valid_tasks == 0:
        return torch.zeros(1, device=device), 0
    
    return loss_total / valid_tasks, valid_tasks


def loss_expected_rtt(logits_per_task, data, device, temperature=1.0):
    """
    Loss Path A: Expected RTT loss over all placements.
    L = E_{π ~ q_θ}[RTT(π)] = Σ_π q_θ(π) * RTT(π)
    where q_θ(π) = Π_t p_θ(π(t)|t) (independent per-task assumption)
    """
    placement_summaries = getattr(data, '_placement_summaries', [])
    if len(placement_summaries) == 0:
        # Log only occasionally to avoid spam
        if hasattr(data, '_debug_logged_expected_rtt') and not data._debug_logged_expected_rtt:
            print(f"[DEBUG loss_expected_rtt] No placement_summaries found (len={len(placement_summaries)})")
            data._debug_logged_expected_rtt = True
        return torch.zeros(1, device=device), 0
    
    n_tasks = data.n_tasks
    plat_pos_by_id = getattr(data, '_plat_pos_by_id', {})
    
    # Get task->platform edge mappings from edge_index
    ei = data.edge_index
    task_to_platforms = {}
    task_to_edge_indices = {}
    
    if ei.numel() > 0:
        ti = ei[0]
        pj = ei[1] - n_tasks
        valid = (pj >= 0) & (pj < data.n_platforms)
        ti_valid = ti[valid]
        pj_valid = pj[valid]
        
        for edge_idx in range(len(ti_valid)):
            t = int(ti_valid[edge_idx].item())
            p = int(pj_valid[edge_idx].item())
            if t not in task_to_platforms:
                task_to_platforms[t] = []
                task_to_edge_indices[t] = []
            task_to_platforms[t].append(p)
            task_to_edge_indices[t].append(edge_idx)
    
    # Convert placement summaries to lookup: placement -> RTT
    placement_rtt_map = {}
    for summary in placement_summaries:
        placement_plan = summary.get('placement_plan', {})
        rtt = summary.get('rtt', float('inf'))
        # Convert placement plan to tuple key: ((task_id, (node_id, plat_id)), ...)
        key_parts = []
        for task_id_str, placement in placement_plan.items():
            task_id = int(task_id_str)
            if isinstance(placement, list) and len(placement) >= 2:
                node_id, plat_id = int(placement[0]), int(placement[1])
                # Map platform_id to platform position
                plat_pos = plat_pos_by_id.get(plat_id, None)
                if plat_pos is not None:
                    key_parts.append((task_id, plat_pos))
        if key_parts:
            key = tuple(sorted(key_parts))
            placement_rtt_map[key] = min(placement_rtt_map.get(key, float('inf')), rtt)
    
    if len(placement_rtt_map) == 0:
        return torch.zeros(1, device=device), 0
    
    # Compute per-task probabilities from logits
    probs_per_task = []
    for t in range(n_tasks):
        if t in task_to_edge_indices:
            edge_indices = task_to_edge_indices[t]
            logits_t = logits_per_task[t]  # (K_t,)
            probs_t = F.softmax(logits_t / temperature, dim=0)  # (K_t,)
            probs_per_task.append({
                'platforms': task_to_platforms[t],
                'probs': probs_t
            })
        else:
            probs_per_task.append(None)
    
    # Compute joint probability for each placement: q_θ(π) = Π_t p_θ(π(t)|t)
    expected_rtt = torch.zeros(1, device=device)
    total_weight = 0.0
    
    for placement_key, rtt in placement_rtt_map.items():
        # Compute joint probability
        log_prob_sum = torch.zeros(1, device=device)
        valid_placement = True
        
        for task_id, plat_pos in placement_key:
            if task_id >= n_tasks or probs_per_task[task_id] is None:
                valid_placement = False
                break
            
            plat_idx_in_task = None
            for idx, p in enumerate(probs_per_task[task_id]['platforms']):
                if p == plat_pos:
                    plat_idx_in_task = idx
                    break
            
            if plat_idx_in_task is None:
                valid_placement = False
                break
            
            prob = probs_per_task[task_id]['probs'][plat_idx_in_task]
            log_prob_sum = log_prob_sum + torch.log(prob + 1e-10)
        
        if valid_placement:
            prob_joint = torch.exp(log_prob_sum)
            expected_rtt = expected_rtt + prob_joint * rtt
            total_weight = total_weight + prob_joint.item()
    
    if total_weight > 0:
        return expected_rtt / total_weight, 1
    return torch.zeros(1, device=device), 0


def loss_conditional_soft_label(logits_per_task, data, device, temperature=1.0, soft_label_temperature=0.1):
    """
    Loss Path B: Conditional soft-label loss (per-task with RTT-based soft labels).
    For each task t, compute min RTT when t is assigned to platform p, then form soft targets.
    y_t(p) ∝ exp(-RTT*(t→p) / τ) where RTT*(t→p) = min over all placements with t→p
    """
    placement_summaries = getattr(data, '_placement_summaries', [])
    if len(placement_summaries) == 0:
        return torch.zeros(1, device=device), 0
    
    n_tasks = data.n_tasks
    plat_pos_by_id = getattr(data, '_plat_pos_by_id', {})
    
    # Get task->platform edge mappings
    ei = data.edge_index
    task_to_platforms = {}
    task_to_edge_indices = {}
    
    if ei.numel() > 0:
        ti = ei[0]
        pj = ei[1] - n_tasks
        valid = (pj >= 0) & (pj < data.n_platforms)
        ti_valid = ti[valid]
        pj_valid = pj[valid]
        
        for edge_idx in range(len(ti_valid)):
            t = int(ti_valid[edge_idx].item())
            p = int(pj_valid[edge_idx].item())
            if t not in task_to_platforms:
                task_to_platforms[t] = []
                task_to_edge_indices[t] = []
            task_to_platforms[t].append(p)
            task_to_edge_indices[t].append(edge_idx)
    
    # For each task, compute min RTT per platform assignment
    loss_total = torch.zeros(1, device=device)
    valid_tasks = 0
    
    for t in range(n_tasks):
        if t not in task_to_platforms:
            continue
        
        # Build RTT lookup for this task: platform_pos -> min RTT
        platform_rtt_map = {}
        
        for summary in placement_summaries:
            placement_plan = summary.get('placement_plan', {})
            rtt = summary.get('rtt', float('inf'))
            
            # Find assignment for task t in this placement
            task_placement = placement_plan.get(str(t), None)
            if task_placement is None:
                continue
            
            if isinstance(task_placement, list) and len(task_placement) >= 2:
                _, plat_id = int(task_placement[0]), int(task_placement[1])
                plat_pos = plat_pos_by_id.get(plat_id, None)
                
                if plat_pos is not None and plat_pos in task_to_platforms[t]:
                    # Update min RTT for this platform
                    if plat_pos not in platform_rtt_map:
                        platform_rtt_map[plat_pos] = rtt
                    else:
                        platform_rtt_map[plat_pos] = min(platform_rtt_map[plat_pos], rtt)
        
        if len(platform_rtt_map) == 0:
            continue
        
        # Build soft labels: y_t(p) ∝ exp(-RTT*(t→p) / τ)
        platforms_for_task = task_to_platforms[t]
        logits_t = logits_per_task[t]  # (K_t,)
        
        # Create soft labels
        rtt_values = []
        for p in platforms_for_task:
            rtt_val = platform_rtt_map.get(p, float('inf'))
            rtt_values.append(rtt_val)
        
        # Normalize RTTs (subtract min for numerical stability)
        if all(r == float('inf') for r in rtt_values):
            continue
        
        min_rtt = min(r for r in rtt_values if r != float('inf'))
        rtt_scores = [-((r - min_rtt) if r != float('inf') else 1000.0) / soft_label_temperature for r in rtt_values]
        
        # Softmax to get soft labels
        rtt_scores_tensor = torch.tensor(rtt_scores, device=device)
        soft_labels = F.softmax(rtt_scores_tensor, dim=0)  # (K_t,)
        
        # Cross-entropy between model probs and soft labels
        probs = F.softmax(logits_t / temperature, dim=0)  # (K_t,)
        loss_t = -torch.sum(soft_labels * torch.log(probs + 1e-10))
        
        loss_total = loss_total + loss_t
        valid_tasks += 1
    
    if valid_tasks == 0:
        return torch.zeros(1, device=device), 0
    
    return loss_total / valid_tasks, valid_tasks

# %%
# ============================================================================
# TRAINING LOOP
# ============================================================================

def train_epoch(model, train_loader, optimizer, device, epoch_num):
    model.train()
    # loss accross all graphs in the batch
    running_ce = 0.0
    running_expected_rtt = 0.0
    running_soft_label = 0.0
    n_steps = 0

    for batch in tqdm(train_loader, desc=f"Epoch {epoch_num:3d} [Train]", leave=False):
        optimizer.zero_grad() # reset gradients
        graphs_in_batch = batch.to_data_list()

        loss_ce_total = torch.zeros(1, device=device)
        loss_expected_rtt_total = torch.zeros(1, device=device)
        loss_soft_label_total = torch.zeros(1, device=device)
        n_graphs = 0

        for data in graphs_in_batch:
            data = data.to(device)
            logits_per_task = model(data)

            # Original CE loss
            loss_ce, valid_ce = loss_original_ce(logits_per_task, data, device)
            if valid_ce > 0:
                loss_ce_total = loss_ce_total + loss_ce
                n_graphs += 1
            
            # Expected RTT loss (only if placement summaries available)
            if hasattr(data, '_placement_summaries') and len(getattr(data, '_placement_summaries', [])) > 0:
                loss_er, valid_er = loss_expected_rtt(logits_per_task, data, device)
                if valid_er > 0:
                    loss_expected_rtt_total = loss_expected_rtt_total + loss_er
            
            # Conditional soft-label loss (only if placement summaries available)
            if hasattr(data, '_placement_summaries') and len(getattr(data, '_placement_summaries', [])) > 0:
                loss_sl, valid_sl = loss_conditional_soft_label(logits_per_task, data, device)
                if valid_sl > 0:
                    loss_soft_label_total = loss_soft_label_total + loss_sl

        if n_graphs == 0:
            # nothing usable in this batch; skip backward to avoid NaNs
            continue

        # Average losses
        loss_ce_avg = loss_ce_total / n_graphs
        
        # Use CE loss for backprop (primary loss)
        loss = loss_ce_avg
        
        # Optional: combine with RTT losses (weighted)
        # Uncomment to use combined loss:
        loss = loss_ce_avg + 0.1 * loss_expected_rtt_total / n_graphs + 0.1 * loss_soft_label_total / n_graphs

        # backpropagate loss
        loss.backward() # compute gradients 

        # Gradient clipping to prevent exploding gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        optimizer.step() # update weights

        running_ce += loss_ce_avg.item()
        running_expected_rtt += loss_expected_rtt_total.item() / max(n_graphs, 1)
        running_soft_label += loss_soft_label_total.item() / max(n_graphs, 1)
        n_steps += 1

    return {
        'ce': running_ce / max(1, n_steps),
        'expected_rtt': running_expected_rtt / max(1, n_steps),
        'soft_label': running_soft_label / max(1, n_steps)
    }

@torch.no_grad()
def decode_predicted_placement(logits_per_task, data):
    """
    Decode model predictions into a placement plan (same format as placement_summaries).
    Returns: Dict[int, List[int, int]] mapping task_id -> [node_id, platform_id]
    """
    n_tasks = data.n_tasks
    plat_pos_by_id = getattr(data, '_plat_pos_by_id', {})
    
    # Reverse mapping: plat_pos -> (platform_id, node_id)
    # We need to extract this from the original data, but for now we'll reconstruct from plat_pos_by_id
    # Create reverse: plat_pos -> platform_id
    plat_id_by_pos = {pos: plat_id for plat_id, pos in plat_pos_by_id.items()}
    
    # Get task->platform edge mappings
    ei = data.edge_index
    task_to_platforms = {}
    
    if ei.numel() > 0:
        ti = ei[0]
        pj = ei[1] - n_tasks
        valid = (pj >= 0) & (pj < data.n_platforms)
        ti_valid = ti[valid]
        pj_valid = pj[valid]
        
        for edge_idx in range(len(ti_valid)):
            t = int(ti_valid[edge_idx].item())
            p = int(pj_valid[edge_idx].item())
            if t not in task_to_platforms:
                task_to_platforms[t] = []
            task_to_platforms[t].append(p)
    
    # Decode greedy placement: argmax per task
    predicted_placement = {}
    
    for task_id in range(n_tasks):
        if task_id not in task_to_platforms or len(logits_per_task[task_id]) == 0:
            continue
        
        # Get argmax platform position for this task
        logits_t = logits_per_task[task_id]
        pred_idx = logits_t.argmax().item()
        
        if pred_idx < len(task_to_platforms[task_id]):
            plat_pos = task_to_platforms[task_id][pred_idx]
            plat_id = plat_id_by_pos.get(plat_pos, None)
            
            if plat_id is not None:
                # We need node_id too - for now use placeholder, but ideally store this
                # Since we don't have node_id in the mapping, we'll need to reconstruct from platform_id
                # For matching, we can use a simplified format or store node_id mapping
                predicted_placement[task_id] = [None, plat_id]  # node_id will be filled from placement_summaries
    
    return predicted_placement


@torch.no_grad()
def compute_rtt_metrics(logits_per_task, data, device):
    """
    Compute RTT-based accuracy metrics using placement summaries.
    Returns dict with: regret, normalized_regret, top_k_acc (k=1,3,5), predicted_rtt, optimal_rtt
    """
    placement_summaries = getattr(data, '_placement_summaries', [])
    if len(placement_summaries) == 0:
        return {
            'regret': 0.0,
            'normalized_regret': 0.0,
            'top1_acc': 0.0,
            'top3_acc': 0.0,
            'top5_acc': 0.0,
            'predicted_rtt': float('inf'),
            'optimal_rtt': float('inf'),
            'num_placements': 0
        }
    
    # Find optimal RTT (minimum RTT across all placements)
    all_rtts = [s.get('rtt', float('inf')) for s in placement_summaries]
    optimal_rtt = min(all_rtts) if all_rtts else float('inf')
    max_rtt = max(all_rtts) if all_rtts else float('inf')
    
    # Decode predicted placement
    predicted_placement = decode_predicted_placement(logits_per_task, data)
    
    # Find predicted placement's RTT
    predicted_rtt = float('inf')
    predicted_key = None
    
    if predicted_placement:
        # Create key for matching (use platform_ids since node_id might be None)
        pred_key_parts = sorted([(int(t), int(p[1])) for t, p in predicted_placement.items() if p[1] is not None])
        
        # Match against placement summaries
        for summary in placement_summaries:
            placement_plan = summary.get('placement_plan', {})
            summary_key_parts = sorted([
                (int(t_str), int(pl[1])) 
                for t_str, pl in placement_plan.items() 
                if isinstance(pl, list) and len(pl) >= 2
            ])
            
            if pred_key_parts == summary_key_parts:
                predicted_rtt = summary.get('rtt', float('inf'))
                predicted_key = tuple(pred_key_parts)
                break
    
    # Compute regret (difference from optimal)
    regret = predicted_rtt - optimal_rtt if predicted_rtt != float('inf') and optimal_rtt != float('inf') else float('inf')
    
    # Normalized regret: (predicted_rtt - optimal_rtt) / (max_rtt - optimal_rtt)
    rtt_range = max_rtt - optimal_rtt if max_rtt != float('inf') and optimal_rtt != float('inf') and max_rtt > optimal_rtt else 1.0
    normalized_regret = regret / rtt_range if rtt_range > 1e-9 else 0.0
    
    # Top-k accuracy: Is predicted placement in top-k by RTT?
    sorted_placements = sorted(placement_summaries, key=lambda s: s.get('rtt', float('inf')))
    top_k_rtts = [s.get('rtt', float('inf')) for s in sorted_placements[:5]]
    
    top1_acc = 1.0 if (len(top_k_rtts) > 0 and predicted_rtt == top_k_rtts[0]) else 0.0
    top3_acc = 1.0 if len(top_k_rtts) >= 3 and predicted_rtt <= top_k_rtts[2] else 0.0
    top5_acc = 1.0 if len(top_k_rtts) >= 5 and predicted_rtt <= top_k_rtts[4] else 0.0
    
    # Additional RTT-based accuracy variants
    within_5pct = 0.0
    within_10pct = 0.0
    if optimal_rtt not in (0.0, float('inf')) and predicted_rtt not in (0.0, float('inf')):
        within_5pct = 1.0 if (predicted_rtt <= optimal_rtt * 1.05) else 0.0
        within_10pct = 1.0 if (predicted_rtt <= optimal_rtt * 1.10) else 0.0

    return {
        'regret': regret if regret != float('inf') else 0.0,
        'normalized_regret': normalized_regret,
        'top1_acc': top1_acc,
        'top3_acc': top3_acc,
        'top5_acc': top5_acc,
        'predicted_rtt': predicted_rtt if predicted_rtt != float('inf') else 0.0,
        'optimal_rtt': optimal_rtt if optimal_rtt != float('inf') else 0.0,
        'rtt_gap': regret if regret != float('inf') else 0.0,
        'rtt_rel_gap': normalized_regret,
        'within_5pct_acc': within_5pct,
        'within_10pct_acc': within_10pct,
        'num_placements': len(placement_summaries)
    }


@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()
    total_loss_ce, total_loss_expected_rtt, total_loss_soft_label = 0.0, 0.0, 0.0
    correct, total = 0, 0
    n_graphs = 0

    # RTT-based metrics accumulators
    total_regret = 0.0
    total_normalized_regret = 0.0
    total_top1 = 0.0
    total_top3 = 0.0
    total_top5 = 0.0
    total_predicted_rtt = 0.0
    total_optimal_rtt = 0.0
    n_rtt_evaluations = 0
    total_within_5pct = 0.0
    total_within_10pct = 0.0


    for batch in loader:
        for data in batch.to_data_list():
            data = data.to(device)
            logits_per_task = model(data)

            # Original CE loss
            loss_ce, valid_ce = loss_original_ce(logits_per_task, data, device)
            if valid_ce > 0:
                total_loss_ce += loss_ce.item() * valid_ce
                total += valid_ce
                n_graphs += 1
                
                # Compute accuracy
                for task_idx, task_logits in enumerate(logits_per_task):
                    if task_logits.numel() == 0:
                        continue

                    logits = task_logits.unsqueeze(0)        # (1, K)

                    target = data.y[task_idx].long()
                    if target.ndim == 0:
                        target = target.unsqueeze(0)         # (1,)
                    if target.item() < 0 or target.item() >= logits.size(1):
                        continue

                    pred = logits.argmax(dim=1).item()       # int
                    correct += int(pred == target.item())
            
            # Expected RTT loss (only if placement summaries available)
            if hasattr(data, '_placement_summaries') and len(getattr(data, '_placement_summaries', [])) > 0:
                loss_er, valid_er = loss_expected_rtt(logits_per_task, data, device)
                if valid_er > 0:
                    total_loss_expected_rtt += loss_er.item()

                # Compute RTT-based metrics
                rtt_metrics = compute_rtt_metrics(logits_per_task, data, device)
                if rtt_metrics['num_placements'] > 0:
                    total_regret += rtt_metrics['regret']
                    total_normalized_regret += rtt_metrics['normalized_regret']
                    total_top1 += rtt_metrics['top1_acc']
                    total_top3 += rtt_metrics['top3_acc']
                    total_top5 += rtt_metrics['top5_acc']
                    total_predicted_rtt += rtt_metrics['predicted_rtt']
                    total_optimal_rtt += rtt_metrics['optimal_rtt']
                    total_within_5pct += rtt_metrics.get('within_5pct_acc', 0.0)
                    total_within_10pct += rtt_metrics.get('within_10pct_acc', 0.0)
                    n_rtt_evaluations += 1
            
            # Conditional soft-label loss (only if placement summaries available)
            if hasattr(data, '_placement_summaries') and len(getattr(data, '_placement_summaries', [])) > 0:
                loss_sl, valid_sl = loss_conditional_soft_label(logits_per_task, data, device)
                if valid_sl > 0:
                    total_loss_soft_label += loss_sl.item()

    avg_loss_ce = total_loss_ce / total if total else 0.0
    avg_loss_expected_rtt = total_loss_expected_rtt / max(n_graphs, 1)
    avg_loss_soft_label = total_loss_soft_label / max(n_graphs, 1)
    acc = correct / total if total else 0.0
    
    # RTT-based metrics (only computed when placement summaries available)
    avg_regret = total_regret / n_rtt_evaluations if n_rtt_evaluations > 0 else 0.0
    avg_normalized_regret = total_normalized_regret / n_rtt_evaluations if n_rtt_evaluations > 0 else 0.0
    top1_acc = total_top1 / n_rtt_evaluations if n_rtt_evaluations > 0 else 0.0
    top3_acc = total_top3 / n_rtt_evaluations if n_rtt_evaluations > 0 else 0.0
    top5_acc = total_top5 / n_rtt_evaluations if n_rtt_evaluations > 0 else 0.0
    avg_predicted_rtt = total_predicted_rtt / n_rtt_evaluations if n_rtt_evaluations > 0 else 0.0
    avg_optimal_rtt = total_optimal_rtt / n_rtt_evaluations if n_rtt_evaluations > 0 else 0.0
    within_5pct_acc = total_within_5pct / n_rtt_evaluations if n_rtt_evaluations > 0 else 0.0
    within_10pct_acc = total_within_10pct / n_rtt_evaluations if n_rtt_evaluations > 0 else 0.0
    
    return {
        'ce': avg_loss_ce,
        'expected_rtt': avg_loss_expected_rtt,
        'soft_label': avg_loss_soft_label,
        'acc': acc,
        'regret': avg_regret,
        'normalized_regret': avg_normalized_regret,
        'top1_acc': top1_acc,
        'top3_acc': top3_acc,
        'top5_acc': top5_acc,
        'predicted_rtt': avg_predicted_rtt,
        'optimal_rtt': avg_optimal_rtt,
        'within_5pct_acc': within_5pct_acc,
        'within_10pct_acc': within_10pct_acc,
        'n_rtt_evaluations': n_rtt_evaluations
    }

# %%
# ========================================================================
# Load all datasets
# ========================================================================
all_datasets = load_all_datasets(BASE_DIR)

if len(all_datasets) == 0:
    print("ERROR: No datasets loaded!")
    exit(1)

# ========================================================================
# Build graphs for all datasets
# ========================================================================
print("Building graphs...")
graphs = []
dataset_ids = []


# Use tqdm to show progress
graphs_with_summaries = 0
total_graph_summaries = 0
for dataset_id, dataset_dict in tqdm(all_datasets.items(), desc="Building graphs", unit="dataset"):
    try:
        graph = build_graph(
            dataset_dict['nodes'],
            dataset_dict['tasks'],
            dataset_dict['platforms']
        )
        # Attach placement summaries as private attribute (PyG will skip during batching)
        # Prefer the internal key used during loading, fallback to old key name
        placement_summaries = dataset_dict.get('_placement_summaries', dataset_dict.get('placement_summaries', []))
        graph._placement_summaries = placement_summaries
        graph._dataset_id = dataset_id
        
        if len(placement_summaries) > 0:
            graphs_with_summaries += 1
            total_graph_summaries += len(placement_summaries)
        
        graphs.append(graph)
        dataset_ids.append(dataset_id)
    except Exception as e:
        tqdm.write(f"  Error building graph for {dataset_id}: {e}")

print(f"\nBuilt {len(graphs)} graphs")
print(f"[DEBUG] Graphs with placement summaries: {graphs_with_summaries}/{len(graphs)} (total summaries: {total_graph_summaries})\n")

# ========================================================================
# Train/Val/Test Split (80/20)
# ========================================================================
train_graphs, test_graphs, train_ids, test_ids = train_test_split(
    graphs, dataset_ids, test_size=0.2, random_state=42
)

print("Dataset split:")
print(f"  Train: {len(train_graphs)} datasets")
print(f"  Test:  {len(test_graphs)} datasets\n")
# Out:
# Loading 3973 datasets...
#   [DEBUG] Loaded 2677 placement summaries from ds_00000
#   [DEBUG] Loaded 967 placement summaries from ds_00003
#   [DEBUG] Loaded 483 placement summaries from ds_00005
#   [DEBUG] Loaded 2379 placement summaries from ds_00010
#   [DEBUG] Loaded 240 placement summaries from ds_00013
#   [DEBUG] Loaded 235 placement summaries from ds_00014
#   [DEBUG] Loaded 480 placement summaries from ds_00015
#   [DEBUG] Loaded 479 placement summaries from ds_00016
#   [DEBUG] Loaded 965 placement summaries from ds_00017
#   [DEBUG] Loaded 237 placement summaries from ds_00018
#   [DEBUG] Loaded 1934 placement summaries from ds_00019
#   [DEBUG] Loaded 1940 placement summaries from ds_00020
#   [DEBUG] Loaded 967 placement summaries from ds_00021
#   [DEBUG] Loaded 966 placement summaries from ds_00022
#   [DEBUG] Loaded 240 placement summaries from ds_00023
#   [DEBUG] Loaded 239 placement summaries from ds_00024
#   [DEBUG] Loaded 482 placement summaries from ds_00025
#   [DEBUG] Loaded 156 placement summaries from ds_00028
#   [DEBUG] Loaded 1494 placement summaries from ds_00030
#   [DEBUG] Loaded 668 placement summaries from ds_00033
#   [DEBUG] Loaded 400 placement summaries from ds_00034
#   [DEBUG] Loaded 213 placement summaries from ds_00035
#   [DEBUG] Loaded 155 placement summaries from ds_00038
#   [DEBUG] Loaded 1344 placement summaries from ds_00039
#   [DEBUG] Loaded 596 placement summaries from ds_00040
#   [DEBUG] Loaded 2005 placement summaries from ds_00041
#   [DEBUG] Loaded 669 placement summaries from ds_00042
#   [DEBUG] Loaded 104 placement summaries from ds_00043
#   [DEBUG] Loaded 157 placement summaries from ds_00044
#   [DEBUG] Loaded 213 placement summaries from ds_00045
#   [DEBUG] Loaded 965 placement summaries from ds_00046
#   [DEBUG] Loaded 1611 placement summaries from ds_00047
#   [DEBUG] Loaded 158 placement summaries from ds_00048
#   [DEBUG] Loaded 1344 placement summaries from ds_00049
#   [DEBUG] Loaded 597 placement summaries from ds_00050
#   [DEBUG] Loaded 2586 placement summaries from ds_00051
#   [DEBUG] Loaded 6 placement summaries from ds_00053
#   [DEBUG] Loaded 2 placement summaries from ds_00054
#   [DEBUG] Loaded 7 placement summaries from ds_00055
#   [DEBUG] Loaded 1 placement summaries from ds_00058
#   [DEBUG] Loaded 102 placement summaries from ds_00060
#   [DEBUG] Loaded 7 placement summaries from ds_00063
#   [DEBUG] Loaded 2 placement summaries from ds_00064
#   [DEBUG] Loaded 6 placement summaries from ds_00065
#   [DEBUG] Loaded 3 placement summaries from ds_00066
#   [DEBUG] Loaded 11 placement summaries from ds_00067
#   [DEBUG] No placement_summary_*.json files found in ds_00068/placements/
#   [DEBUG] Loaded 17 placement summaries from ds_00069
#   [DEBUG] Loaded 68 placement summaries from ds_00070
#   [DEBUG] Loaded 28 placement summaries from ds_00071
#   [DEBUG] Loaded 8 placement summaries from ds_00072
#   [DEBUG] Loaded 2 placement summaries from ds_00073
#   [DEBUG] Loaded 1 placement summaries from ds_00074
#   [DEBUG] Loaded 4 placement summaries from ds_00075
#   [DEBUG] Loaded 2 placement summaries from ds_00076
#   [DEBUG] Loaded 10 placement summaries from ds_00077
#   [DEBUG] Loaded 426 placement summaries from ds_00083
#   [DEBUG] Loaded 318 placement summaries from ds_00092
#   [DEBUG] Loaded 25 placement summaries from ds_00093
#   [DEBUG] Loaded 78 placement summaries from ds_00094
#   [DEBUG] Loaded 479 placement summaries from ds_00096
#   [DEBUG] Loaded 640 placement summaries from ds_00097
#   [DEBUG] Loaded 855 placement summaries from ds_00099
#   [DEBUG] Loaded 318 placement summaries from ds_00102
#   [DEBUG] Loaded 25 placement summaries from ds_00103
#   [DEBUG] Loaded 510 placement summaries from ds_00130
#   [DEBUG] Loaded 122 placement summaries from ds_00133
#   [DEBUG] Loaded 58 placement summaries from ds_00134
#   [DEBUG] Loaded 61 placement summaries from ds_00135
#   [DEBUG] Loaded 31 placement summaries from ds_00138
#   [DEBUG] Loaded 503 placement summaries from ds_00140
#   [DEBUG] Loaded 28 placement summaries from ds_00143
#   [DEBUG] Loaded 28 placement summaries from ds_00144
#   [DEBUG] Loaded 59 placement summaries from ds_00145
#   [DEBUG] Loaded 122 placement summaries from ds_00146
#   [DEBUG] Loaded 248 placement summaries from ds_00147
#   [DEBUG] Loaded 28 placement summaries from ds_00148
#   [DEBUG] Loaded 249 placement summaries from ds_00149
#   [DEBUG] Loaded 250 placement summaries from ds_00150
#   [DEBUG] Loaded 508 placement summaries from ds_00151
#   [DEBUG] Loaded 123 placement summaries from ds_00152
#   [DEBUG] Loaded 29 placement summaries from ds_00153
#   [DEBUG] Loaded 31 placement summaries from ds_00154
#   [DEBUG] Loaded 58 placement summaries from ds_00155
#   [DEBUG] Loaded 17 placement summaries from ds_00160
#   [DEBUG] Loaded 62 placement summaries from ds_00163
#   [DEBUG] Loaded 61 placement summaries from ds_00165
#   [DEBUG] Loaded 195 placement summaries from ds_00170
#   [DEBUG] Loaded 1017 placement summaries from ds_00171
#   [DEBUG] Loaded 250 placement summaries from ds_00174
#   [DEBUG] Loaded 121 placement summaries from ds_00175
#   [DEBUG] Loaded 194 placement summaries from ds_00180
#   [DEBUG] Loaded 1015 placement summaries from ds_00181
#   [DEBUG] Loaded 125 placement summaries from ds_00183
#   [DEBUG] Loaded 61 placement summaries from ds_00184
#   [DEBUG] Loaded 60 placement summaries from ds_00185
#   [DEBUG] Loaded 28 placement summaries from ds_00188
#   [DEBUG] Loaded 497 placement summaries from ds_00190
#   [DEBUG] Loaded 124 placement summaries from ds_00193
#   [DEBUG] Loaded 58 placement summaries from ds_00194
#   [DEBUG] Loaded 63 placement summaries from ds_00195
#   [DEBUG] Loaded 125 placement summaries from ds_00196
#   [DEBUG] Loaded 249 placement summaries from ds_00197
#   [DEBUG] Loaded 27 placement summaries from ds_00198
#   [DEBUG] Loaded 251 placement summaries from ds_00199
#   [DEBUG] Loaded 254 placement summaries from ds_00200
#   [DEBUG] Loaded 506 placement summaries from ds_00201
#   [DEBUG] Loaded 123 placement summaries from ds_00202
#   [DEBUG] Loaded 30 placement summaries from ds_00203
#   [DEBUG] Loaded 30 placement summaries from ds_00204
#   [DEBUG] Loaded 60 placement summaries from ds_00205
#   [DEBUG] Loaded 122 placement summaries from ds_00206
#   [DEBUG] Loaded 253 placement summaries from ds_00207
#   [DEBUG] Loaded 59 placement summaries from ds_00213
#   [DEBUG] Loaded 252 placement summaries from ds_00224
#   [DEBUG] Loaded 62 placement summaries from ds_00235
#   [DEBUG] Loaded 503 placement summaries from ds_00240
#   [DEBUG] Loaded 122 placement summaries from ds_00243
#   [DEBUG] Loaded 61 placement summaries from ds_00245
#   [DEBUG] Loaded 125 placement summaries from ds_00247
#   [DEBUG] Loaded 30 placement summaries from ds_00248
#   [DEBUG] Loaded 247 placement summaries from ds_00249
#   [DEBUG] Loaded 250 placement summaries from ds_00250
#   [DEBUG] Loaded 122 placement summaries from ds_00251
#   [DEBUG] Loaded 123 placement summaries from ds_00252
#   [DEBUG] Loaded 28 placement summaries from ds_00253
#   [DEBUG] Loaded 29 placement summaries from ds_00254
#   [DEBUG] Loaded 62 placement summaries from ds_00255
#   [DEBUG] Loaded 60 placement summaries from ds_00256
#   [DEBUG] Loaded 125 placement summaries from ds_00257
#   [DEBUG] Loaded 30 placement summaries from ds_00258
#   [DEBUG] Loaded 252 placement summaries from ds_00259
#   [DEBUG] Loaded 1494 placement summaries from ds_00260
#   [DEBUG] Loaded 290 placement summaries from ds_00262
#   [DEBUG] Loaded 196 placement summaries from ds_00263
#   [DEBUG] Loaded 79 placement summaries from ds_00264
#   [DEBUG] Loaded 143 placement summaries from ds_00265
#   [DEBUG] Loaded 47 placement summaries from ds_00268
#   [DEBUG] Loaded 592 placement summaries from ds_00269
#   [DEBUG] Loaded 1489 placement summaries from ds_00270
#   [DEBUG] Loaded 290 placement summaries from ds_00272
#   [DEBUG] Loaded 71 placement summaries from ds_00273
#   [DEBUG] Loaded 46 placement summaries from ds_00274
#   [DEBUG] Loaded 141 placement summaries from ds_00275
#   [DEBUG] Loaded 123 placement summaries from ds_00276
#   [DEBUG] Loaded 795 placement summaries from ds_00277
#   [DEBUG] Loaded 47 placement summaries from ds_00278
#   [DEBUG] Loaded 993 placement summaries from ds_00279
#   [DEBUG] Loaded 893 placement summaries from ds_00280
#   [DEBUG] Loaded 765 placement summaries from ds_00281
#   [DEBUG] Loaded 493 placement summaries from ds_00282
#   [DEBUG] Loaded 71 placement summaries from ds_00283
#   [DEBUG] Loaded 39 placement summaries from ds_00284
#   [DEBUG] Loaded 140 placement summaries from ds_00285
#   [DEBUG] Loaded 12 placement summaries from ds_00288
#   [DEBUG] Loaded 105 placement summaries from ds_00290
#   [DEBUG] Loaded 70 placement summaries from ds_00293
#   [DEBUG] Loaded 44 placement summaries from ds_00294
#   [DEBUG] Loaded 15 placement summaries from ds_00295
#   [DEBUG] Loaded 13 placement summaries from ds_00298
#   [DEBUG] Loaded 142 placement summaries from ds_00299
#   [DEBUG] Loaded 32 placement summaries from ds_00300
#   [DEBUG] Loaded 253 placement summaries from ds_00301
#   [DEBUG] Loaded 69 placement summaries from ds_00302
#   [DEBUG] Loaded 7 placement summaries from ds_00303
#   [DEBUG] Loaded 12 placement summaries from ds_00304
#   [DEBUG] Loaded 13 placement summaries from ds_00305
#   [DEBUG] Loaded 118 placement summaries from ds_00306
#   [DEBUG] Loaded 187 placement summaries from ds_00307
#   [DEBUG] Loaded 13 placement summaries from ds_00308
#   [DEBUG] Loaded 140 placement summaries from ds_00309
#   [DEBUG] Loaded 32 placement summaries from ds_00310
#   [DEBUG] Loaded 254 placement summaries from ds_00311
#   [DEBUG] Loaded 572 placement summaries from ds_00312
#   [DEBUG] Loaded 2293 placement summaries from ds_00313
#   [DEBUG] Loaded 763 placement summaries from ds_00314
#   [DEBUG] Loaded 504 placement summaries from ds_00315
#   [DEBUG] Loaded 248 placement summaries from ds_00318
#   [DEBUG] Loaded 2295 placement summaries from ds_00319
#   [DEBUG] Loaded 1662 placement summaries from ds_00320
#   [DEBUG] Loaded 565 placement summaries from ds_00322
#   [DEBUG] Loaded 2047 placement summaries from ds_00323
#   [DEBUG] Loaded 764 placement summaries from ds_00324
#   [DEBUG] Loaded 505 placement summaries from ds_00325
#   [DEBUG] Loaded 1793 placement summaries from ds_00326
#   [DEBUG] Loaded 2107 placement summaries from ds_00327
#   [DEBUG] Loaded 763 placement summaries from ds_00328
#   [DEBUG] Loaded 2063 placement summaries from ds_00329
#   [DEBUG] Loaded 1143 placement summaries from ds_00330
#   [DEBUG] Loaded 1870 placement summaries from ds_00331
#   [DEBUG] Loaded 3026 placement summaries from ds_00332
#   [DEBUG] Loaded 254 placement summaries from ds_00333
#   [DEBUG] Loaded 761 placement summaries from ds_00334
#   [DEBUG] Loaded 507 placement summaries from ds_00335
#   [DEBUG] Loaded 1584 placement summaries from ds_00336
#   [DEBUG] Loaded 1884 placement summaries from ds_00337
#   [DEBUG] Loaded 2 placement summaries from ds_00338
#   [DEBUG] Loaded 382 placement summaries from ds_00340
#   [DEBUG] Loaded 13 placement summaries from ds_00343
#   [DEBUG] Loaded 3 placement summaries from ds_00344
#   [DEBUG] Loaded 14 placement summaries from ds_00345
#   [DEBUG] Loaded 2 placement summaries from ds_00348
#   [DEBUG] Loaded 377 placement summaries from ds_00350
#   [DEBUG] Loaded 47 placement summaries from ds_00351
#   [DEBUG] Loaded 12 placement summaries from ds_00352
#   [DEBUG] Loaded 7 placement summaries from ds_00353
#   [DEBUG] Loaded 1 placement summaries from ds_00354
#   [DEBUG] Loaded 15 placement summaries from ds_00355
#   [DEBUG] Loaded 3 placement summaries from ds_00356
#   [DEBUG] Loaded 15 placement summaries from ds_00357
#   [DEBUG] Loaded 2 placement summaries from ds_00358
#   [DEBUG] Loaded 30 placement summaries from ds_00359
#   [DEBUG] Loaded 277 placement summaries from ds_00360
#   [DEBUG] Loaded 43 placement summaries from ds_00361
#   [DEBUG] Loaded 12 placement summaries from ds_00362
#   [DEBUG] Loaded 7 placement summaries from ds_00363
#   [DEBUG] Loaded 1 placement summaries from ds_00364
#   [DEBUG] Loaded 3 placement summaries from ds_00373
#   [DEBUG] Loaded 1 placement summaries from ds_00374
#   [DEBUG] Loaded 6 placement summaries from ds_00377
#   [DEBUG] Loaded 5 placement summaries from ds_00379
#   [DEBUG] Loaded 3 placement summaries from ds_00382
#   [DEBUG] No placement_summary_*.json files found in ds_00383/placements/
#   [DEBUG] No placement_summary_*.json files found in ds_00384/placements/
#   [DEBUG] Loaded 2 placement summaries from ds_00386
#   [DEBUG] Loaded 6 placement summaries from ds_00387
#   [DEBUG] Loaded 4 placement summaries from ds_00389
#   [DEBUG] Loaded 2907 placement summaries from ds_00390
#   [DEBUG] Loaded 1569 placement summaries from ds_00400
#   [DEBUG] Loaded 237 placement summaries from ds_00403
#   [DEBUG] Loaded 480 placement summaries from ds_00404
#   [DEBUG] Loaded 1839 placement summaries from ds_00405
#   [DEBUG] Loaded 965 placement summaries from ds_00406
#   [DEBUG] Loaded 970 placement summaries from ds_00407
#   [DEBUG] Loaded 966 placement summaries from ds_00408
#   [DEBUG] Loaded 1733 placement summaries from ds_00409
#   [DEBUG] Loaded 1527 placement summaries from ds_00410
#   [DEBUG] Loaded 1935 placement summaries from ds_00411
#   [DEBUG] Loaded 1934 placement summaries from ds_00412
#   [DEBUG] Loaded 236 placement summaries from ds_00413
#   [DEBUG] Loaded 479 placement summaries from ds_00414
#   [DEBUG] Loaded 1939 placement summaries from ds_00415
#   [DEBUG] Loaded 1645 placement summaries from ds_00420
#   [DEBUG] Loaded 400 placement summaries from ds_00421
#   [DEBUG] Loaded 1342 placement summaries from ds_00429
#   [DEBUG] Loaded 1493 placement summaries from ds_00430
#   [DEBUG] Loaded 2991 placement summaries from ds_00431
#   [DEBUG] Loaded 2694 placement summaries from ds_00432
#   [DEBUG] Loaded 428 placement summaries from ds_00433
#   [DEBUG] Loaded 2509 placement summaries from ds_00434
#   [DEBUG] Loaded 3131 placement summaries from ds_00435
#   [DEBUG] Loaded 3877 placement summaries from ds_00436
#   [DEBUG] Loaded 1735 placement summaries from ds_00437
#   [DEBUG] Loaded 1609 placement summaries from ds_00438
#   [DEBUG] Loaded 1339 placement summaries from ds_00439
#   [DEBUG] Loaded 1495 placement summaries from ds_00440
#   [DEBUG] Loaded 4534 placement summaries from ds_00441
#   [DEBUG] Loaded 86 placement summaries from ds_00450
#   [DEBUG] Loaded 1 placement summaries from ds_00451
#   [DEBUG] Loaded 68 placement summaries from ds_00455
#   [DEBUG] Loaded 12 placement summaries from ds_00456
#   [DEBUG] Loaded 19 placement summaries from ds_00457
#   [DEBUG] Loaded 9 placement summaries from ds_00458
#   [DEBUG] Loaded 17 placement summaries from ds_00459
#   [DEBUG] Loaded 102 placement summaries from ds_00460
#   [DEBUG] Loaded 45 placement summaries from ds_00461
#   [DEBUG] Loaded 35 placement summaries from ds_00462
#   [DEBUG] Loaded 11 placement summaries from ds_00463
#   [DEBUG] Loaded 29 placement summaries from ds_00464
#   [DEBUG] Loaded 67 placement summaries from ds_00465
#   [DEBUG] Loaded 15 placement summaries from ds_00466
#   [DEBUG] Loaded 22 placement summaries from ds_00467
#   [DEBUG] Loaded 204 placement summaries from ds_00470
#   [DEBUG] Loaded 210 placement summaries from ds_00480
#   [DEBUG] Loaded 964 placement summaries from ds_00481
#   [DEBUG] Loaded 645 placement summaries from ds_00482
#   [DEBUG] Loaded 24 placement summaries from ds_00483
#   [DEBUG] Loaded 159 placement summaries from ds_00484
#   [DEBUG] Loaded 481 placement summaries from ds_00485
#   [DEBUG] Loaded 967 placement summaries from ds_00486
#   [DEBUG] Loaded 639 placement summaries from ds_00487
#   [DEBUG] Loaded 481 placement summaries from ds_00488
#   [DEBUG] Loaded 859 placement summaries from ds_00489
#   [DEBUG] Loaded 213 placement summaries from ds_00490
#   [DEBUG] Loaded 962 placement summaries from ds_00491
#   [DEBUG] Loaded 641 placement summaries from ds_00492
#   [DEBUG] Loaded 26 placement summaries from ds_00493
#   [DEBUG] Loaded 1019 placement summaries from ds_00508
#   [DEBUG] Loaded 1766 placement summaries from ds_00511
#   [DEBUG] Loaded 2038 placement summaries from ds_00515
#   [DEBUG] Loaded 2043 placement summaries from ds_00516
#   [DEBUG] Loaded 1018 placement summaries from ds_00518
#   [DEBUG] Loaded 504 placement summaries from ds_00520
#   [DEBUG] Loaded 58 placement summaries from ds_00521
#   [DEBUG] Loaded 505 placement summaries from ds_00530
#   [DEBUG] Loaded 60 placement summaries from ds_00531
#   [DEBUG] Loaded 125 placement summaries from ds_00533
#   [DEBUG] Loaded 504 placement summaries from ds_00534
#   [DEBUG] Loaded 1012 placement summaries from ds_00535
#   [DEBUG] Loaded 508 placement summaries from ds_00536
#   [DEBUG] Loaded 507 placement summaries from ds_00537
#   [DEBUG] Loaded 250 placement summaries from ds_00538
#   [DEBUG] Loaded 254 placement summaries from ds_00539
#   [DEBUG] Loaded 506 placement summaries from ds_00540
#   [DEBUG] Loaded 1015 placement summaries from ds_00541
#   [DEBUG] Loaded 510 placement summaries from ds_00542
#   [DEBUG] Loaded 122 placement summaries from ds_00543
#   [DEBUG] Loaded 506 placement summaries from ds_00544
#   [DEBUG] Loaded 1019 placement summaries from ds_00545
#   [DEBUG] Loaded 893 placement summaries from ds_00550
#   [DEBUG] Loaded 195 placement summaries from ds_00560
#   [DEBUG] Loaded 2738 placement summaries from ds_00561
#   [DEBUG] Loaded 61 placement summaries from ds_00563
#   [DEBUG] Loaded 251 placement summaries from ds_00564
#   [DEBUG] Loaded 1899 placement summaries from ds_00565
#   [DEBUG] Loaded 2040 placement summaries from ds_00566
#   [DEBUG] Loaded 1272 placement summaries from ds_00568
#   [DEBUG] Loaded 196 placement summaries from ds_00570
#   [DEBUG] Loaded 3081 placement summaries from ds_00571
#   [DEBUG] Loaded 507 placement summaries from ds_00580
#   [DEBUG] Loaded 60 placement summaries from ds_00581
#   [DEBUG] Loaded 1017 placement summaries from ds_00585
#   [DEBUG] Loaded 502 placement summaries from ds_00586
#   [DEBUG] Loaded 510 placement summaries from ds_00587
#   [DEBUG] Loaded 252 placement summaries from ds_00588
#   [DEBUG] Loaded 245 placement summaries from ds_00589
#   [DEBUG] Loaded 509 placement summaries from ds_00590
#   [DEBUG] Loaded 1018 placement summaries from ds_00591
#   [DEBUG] Loaded 505 placement summaries from ds_00592
#   [DEBUG] Loaded 121 placement summaries from ds_00593
#   [DEBUG] Loaded 507 placement summaries from ds_00594
#   [DEBUG] Loaded 1015 placement summaries from ds_00595
#   [DEBUG] Loaded 508 placement summaries from ds_00596
#   [DEBUG] Loaded 511 placement summaries from ds_00597
#   [DEBUG] Loaded 714 placement summaries from ds_00600
#   [DEBUG] Loaded 715 placement summaries from ds_00610
#   [DEBUG] Loaded 4087 placement summaries from ds_00611
#   [DEBUG] Loaded 59 placement summaries from ds_00613
#   [DEBUG] Loaded 252 placement summaries from ds_00614
#   [DEBUG] Loaded 2038 placement summaries from ds_00615
#   [DEBUG] Loaded 1514 placement summaries from ds_00616
#   [DEBUG] Loaded 1020 placement summaries from ds_00618
#   [DEBUG] Loaded 152 placement summaries from ds_00620
#   [DEBUG] Loaded 1776 placement summaries from ds_00621
#   [DEBUG] Loaded 61 placement summaries from ds_00623
#   [DEBUG] Loaded 375 placement summaries from ds_00630
#   [DEBUG] Loaded 125 placement summaries from ds_00637
#   [DEBUG] Loaded 124 placement summaries from ds_00638
#   [DEBUG] Loaded 249 placement summaries from ds_00639
#   [DEBUG] Loaded 504 placement summaries from ds_00640
#   [DEBUG] Loaded 253 placement summaries from ds_00641
#   [DEBUG] Loaded 248 placement summaries from ds_00642
#   [DEBUG] Loaded 29 placement summaries from ds_00643
#   [DEBUG] Loaded 60 placement summaries from ds_00644
#   [DEBUG] Loaded 253 placement summaries from ds_00645
#   [DEBUG] Loaded 124 placement summaries from ds_00646
#   [DEBUG] Loaded 127 placement summaries from ds_00647
#   [DEBUG] Loaded 122 placement summaries from ds_00648
#   [DEBUG] Loaded 248 placement summaries from ds_00649
#   [DEBUG] Loaded 1340 placement summaries from ds_00650
#   [DEBUG] Loaded 77 placement summaries from ds_00651
#   [DEBUG] Loaded 597 placement summaries from ds_00659
#   [DEBUG] Loaded 1344 placement summaries from ds_00660
#   [DEBUG] Loaded 78 placement summaries from ds_00661
#   [DEBUG] Loaded 284 placement summaries from ds_00663
#   [DEBUG] Loaded 763 placement summaries from ds_00664
#   [DEBUG] Loaded 1595 placement summaries from ds_00665
#   [DEBUG] Loaded 500 placement summaries from ds_00666
#   [DEBUG] Loaded 1592 placement summaries from ds_00667
#   [DEBUG] Loaded 318 placement summaries from ds_00668
#   [DEBUG] Loaded 994 placement summaries from ds_00669
#   [DEBUG] Loaded 1496 placement summaries from ds_00670
#   [DEBUG] Loaded 1274 placement summaries from ds_00671
#   [DEBUG] Loaded 1993 placement summaries from ds_00672
#   [DEBUG] Loaded 285 placement summaries from ds_00673
#   [DEBUG] Loaded 761 placement summaries from ds_00674
#   [DEBUG] Loaded 1596 placement summaries from ds_00675
#   [DEBUG] Loaded 122 placement summaries from ds_00680
#   [DEBUG] Loaded 44 placement summaries from ds_00681
#   [DEBUG] Loaded 139 placement summaries from ds_00689
#   [DEBUG] Loaded 102 placement summaries from ds_00690
#   [DEBUG] Loaded 761 placement summaries from ds_00691
#   [DEBUG] Loaded 278 placement summaries from ds_00692
#   [DEBUG] Loaded 31 placement summaries from ds_00693
#   [DEBUG] Loaded 253 placement summaries from ds_00694
#   [DEBUG] Loaded 564 placement summaries from ds_00695
#   [DEBUG] Loaded 505 placement summaries from ds_00696
#   [DEBUG] Loaded 379 placement summaries from ds_00697
#   [DEBUG] Loaded 183 placement summaries from ds_00698
#   [DEBUG] Loaded 142 placement summaries from ds_00699
#   [DEBUG] Loaded 101 placement summaries from ds_00700
#   [DEBUG] Loaded 758 placement summaries from ds_00701
#   [DEBUG] Loaded 2002 placement summaries from ds_00709
#   [DEBUG] Loaded 1915 placement summaries from ds_00710
#   [DEBUG] Loaded 1527 placement summaries from ds_00715
#   [DEBUG] Loaded 4040 placement summaries from ds_00716
#   [DEBUG] Loaded 3652 placement summaries from ds_00717
#   [DEBUG] Loaded 2367 placement summaries from ds_00718
#   [DEBUG] Loaded 1644 placement summaries from ds_00719
#   [DEBUG] Loaded 3446 placement summaries from ds_00720
#   [DEBUG] Loaded 1777 placement summaries from ds_00721
#   [DEBUG] Loaded 2449 placement summaries from ds_00722
#   [DEBUG] Loaded 251 placement summaries from ds_00723
#   [DEBUG] Loaded 1275 placement summaries from ds_00724
#   [DEBUG] Loaded 1854 placement summaries from ds_00725
#   [DEBUG] Loaded 2304 placement summaries from ds_00726
#   [DEBUG] Loaded 1556 placement summaries from ds_00727
#   [DEBUG] Loaded 284 placement summaries from ds_00730
#   [DEBUG] Loaded 3 placement summaries from ds_00731
#   [DEBUG] Loaded 283 placement summaries from ds_00740
#   [DEBUG] Loaded 57 placement summaries from ds_00741
#   [DEBUG] Loaded 61 placement summaries from ds_00742
#   [DEBUG] Loaded 33 placement summaries from ds_00743
#   [DEBUG] Loaded 46 placement summaries from ds_00744
#   [DEBUG] Loaded 127 placement summaries from ds_00745
#   [DEBUG] Loaded 14 placement summaries from ds_00746
#   [DEBUG] Loaded 31 placement summaries from ds_00747
#   [DEBUG] Loaded 13 placement summaries from ds_00748
#   [DEBUG] Loaded 31 placement summaries from ds_00749
#   [DEBUG] Loaded 377 placement summaries from ds_00750
#   [DEBUG] Loaded 61 placement summaries from ds_00751
#   [DEBUG] Loaded 54 placement summaries from ds_00752
#   [DEBUG] Loaded 32 placement summaries from ds_00753
#   [DEBUG] Loaded 7 placement summaries from ds_00760
#   [DEBUG] No placement_summary_*.json files found in ds_00761/placements/
#   [DEBUG] Loaded 14 placement summaries from ds_00767
#   [DEBUG] Loaded 1 placement summaries from ds_00768
#   [DEBUG] Loaded 6 placement summaries from ds_00769
#   [DEBUG] Loaded 5 placement summaries from ds_00770
#   [DEBUG] Loaded 12 placement summaries from ds_00771
#   [DEBUG] Loaded 13 placement summaries from ds_00772
#   [DEBUG] Loaded 3 placement summaries from ds_00773
#   [DEBUG] Loaded 12 placement summaries from ds_00774
#   [DEBUG] Loaded 6 placement summaries from ds_00775
#   [DEBUG] Loaded 14 placement summaries from ds_00776
#   [DEBUG] Loaded 12 placement summaries from ds_00777
#   [DEBUG] Loaded 3 placement summaries from ds_00778
#   [DEBUG] Loaded 6 placement summaries from ds_00779
#   [DEBUG] Loaded 2901 placement summaries from ds_00780
#   [DEBUG] Loaded 235 placement summaries from ds_00781
#   [DEBUG] Loaded 1867 placement summaries from ds_00782
#   [DEBUG] Loaded 969 placement summaries from ds_00783
#   [DEBUG] Loaded 967 placement summaries from ds_00784
#   [DEBUG] Loaded 239 placement summaries from ds_00785
#   [DEBUG] Loaded 483 placement summaries from ds_00786
#   [DEBUG] Loaded 965 placement summaries from ds_00787
#   [DEBUG] Loaded 476 placement summaries from ds_00788
#   [DEBUG] Loaded 1915 placement summaries from ds_00789
#   [DEBUG] Loaded 3350 placement summaries from ds_00790
#   [DEBUG] Loaded 238 placement summaries from ds_00791
#   [DEBUG] Loaded 4746 placement summaries from ds_00792
#   [DEBUG] Loaded 5361 placement summaries from ds_00793
#   [DEBUG] Loaded 2031 placement summaries from ds_00794
#   [DEBUG] Loaded 2318 placement summaries from ds_00795
#   [DEBUG] Loaded 1940 placement summaries from ds_00796
#   [DEBUG] Loaded 969 placement summaries from ds_00797
#   [DEBUG] Loaded 1990 placement summaries from ds_00798
#   [DEBUG] Loaded 968 placement summaries from ds_00799
#   [DEBUG] Loaded 1570 placement summaries from ds_00800
#   [DEBUG] Loaded 476 placement summaries from ds_00801
#   [DEBUG] Loaded 5822 placement summaries from ds_00802
#   [DEBUG] Loaded 4101 placement summaries from ds_00803
#   [DEBUG] Loaded 4027 placement summaries from ds_00804
#   [DEBUG] Loaded 1539 placement summaries from ds_00805
#   [DEBUG] Loaded 1615 placement summaries from ds_00806
#   [DEBUG] Loaded 1612 placement summaries from ds_00807
#   [DEBUG] Loaded 1935 placement summaries from ds_00808
#   [DEBUG] Loaded 2692 placement summaries from ds_00809
#   [DEBUG] Loaded 2425 placement summaries from ds_00810
#   [DEBUG] Loaded 639 placement summaries from ds_00811
#   [DEBUG] Loaded 3326 placement summaries from ds_00812
#   [DEBUG] Loaded 1345 placement summaries from ds_00813
#   [DEBUG] Loaded 1205 placement summaries from ds_00814
#   [DEBUG] Loaded 104 placement summaries from ds_00815
#   [DEBUG] Loaded 2906 placement summaries from ds_00816
#   [DEBUG] Loaded 1614 placement summaries from ds_00817
#   [DEBUG] Loaded 1936 placement summaries from ds_00818
#   [DEBUG] Loaded 645 placement summaries from ds_00819
#   [DEBUG] Loaded 1914 placement summaries from ds_00820
#   [DEBUG] Loaded 400 placement summaries from ds_00821
#   [DEBUG] Loaded 2318 placement summaries from ds_00822
#   [DEBUG] Loaded 2664 placement summaries from ds_00823
#   [DEBUG] Loaded 3640 placement summaries from ds_00824
#   [DEBUG] Loaded 1760 placement summaries from ds_00825
#   [DEBUG] Loaded 1675 placement summaries from ds_00826
#   [DEBUG] Loaded 1453 placement summaries from ds_00827
#   [DEBUG] Loaded 3350 placement summaries from ds_00828
#   [DEBUG] Loaded 642 placement summaries from ds_00829
#   [DEBUG] Loaded 1912 placement summaries from ds_00830
#   [DEBUG] Loaded 401 placement summaries from ds_00831
#   [DEBUG] Loaded 123 placement summaries from ds_00832
#   [DEBUG] Loaded 14 placement summaries from ds_00833
#   [DEBUG] Loaded 8 placement summaries from ds_00834
#   [DEBUG] Loaded 2 placement summaries from ds_00835
#   [DEBUG] Loaded 10 placement summaries from ds_00836
#   [DEBUG] Loaded 10 placement summaries from ds_00837
#   [DEBUG] Loaded 23 placement summaries from ds_00838
#   [DEBUG] Loaded 32 placement summaries from ds_00839
#   [DEBUG] Loaded 123 placement summaries from ds_00840
#   [DEBUG] Loaded 5 placement summaries from ds_00841
#   [DEBUG] Loaded 122 placement summaries from ds_00842
#   [DEBUG] Loaded 15 placement summaries from ds_00843
#   [DEBUG] Loaded 8 placement summaries from ds_00844
#   [DEBUG] Loaded 76 placement summaries from ds_00845
#   [DEBUG] Loaded 10 placement summaries from ds_00846
#   [DEBUG] Loaded 15 placement summaries from ds_00847
#   [DEBUG] Loaded 68 placement summaries from ds_00848
#   [DEBUG] Loaded 21 placement summaries from ds_00849
#   [DEBUG] Loaded 93 placement summaries from ds_00850
#   [DEBUG] Loaded 1 placement summaries from ds_00851
#   [DEBUG] Loaded 140 placement summaries from ds_00852
#   [DEBUG] Loaded 283 placement summaries from ds_00853
#   [DEBUG] Loaded 211 placement summaries from ds_00854
#   [DEBUG] Loaded 77 placement summaries from ds_00855
#   [DEBUG] Loaded 10 placement summaries from ds_00856
#   [DEBUG] Loaded 17 placement summaries from ds_00857
#   [DEBUG] Loaded 855 placement summaries from ds_00859
#   [DEBUG] Loaded 2018 placement summaries from ds_00862
#   [DEBUG] Loaded 428 placement summaries from ds_00863
#   [DEBUG] Loaded 643 placement summaries from ds_00864
#   [DEBUG] Loaded 482 placement summaries from ds_00866
#   [DEBUG] Loaded 636 placement summaries from ds_00867
#   [DEBUG] Loaded 858 placement summaries from ds_00869
#   [DEBUG] Loaded 237 placement summaries from ds_00871
#   [DEBUG] Loaded 1291 placement summaries from ds_00872
#   [DEBUG] Loaded 1615 placement summaries from ds_00873
#   [DEBUG] Loaded 1734 placement summaries from ds_00874
#   [DEBUG] Loaded 968 placement summaries from ds_00875
#   [DEBUG] Loaded 1612 placement summaries from ds_00876
#   [DEBUG] Loaded 319 placement summaries from ds_00877
#   [DEBUG] Loaded 2543 placement summaries from ds_00878
#   [DEBUG] Loaded 107 placement summaries from ds_00879
#   [DEBUG] Loaded 214 placement summaries from ds_00880
#   [DEBUG] Loaded 238 placement summaries from ds_00881
#   [DEBUG] Loaded 1289 placement summaries from ds_00882
#   [DEBUG] Loaded 3446 placement summaries from ds_00883
#   [DEBUG] Loaded 1614 placement summaries from ds_00884
#   [DEBUG] Loaded 1013 placement summaries from ds_00889
#   [DEBUG] Loaded 3909 placement summaries from ds_00892
#   [DEBUG] Loaded 1013 placement summaries from ds_00893
#   [DEBUG] Loaded 1735 placement summaries from ds_00894
#   [DEBUG] Loaded 2304 placement summaries from ds_00898
#   [DEBUG] Loaded 2043 placement summaries from ds_00903
#   [DEBUG] Loaded 2045 placement summaries from ds_00904
#   [DEBUG] Loaded 2419 placement summaries from ds_00908
#   [DEBUG] Loaded 763 placement summaries from ds_00910
#   [DEBUG] Loaded 127 placement summaries from ds_00911
#   [DEBUG] Loaded 2229 placement summaries from ds_00912
#   [DEBUG] Loaded 249 placement summaries from ds_00913
#   [DEBUG] Loaded 188 placement summaries from ds_00914
#   [DEBUG] Loaded 30 placement summaries from ds_00915
#   [DEBUG] Loaded 372 placement summaries from ds_00916
#   [DEBUG] Loaded 251 placement summaries from ds_00917
#   [DEBUG] Loaded 377 placement summaries from ds_00918
#   [DEBUG] Loaded 504 placement summaries from ds_00919
#   [DEBUG] Loaded 758 placement summaries from ds_00920
#   [DEBUG] Loaded 123 placement summaries from ds_00921
#   [DEBUG] Loaded 1853 placement summaries from ds_00922
#   [DEBUG] Loaded 2501 placement summaries from ds_00923
#   [DEBUG] Loaded 4193 placement summaries from ds_00924
#   [DEBUG] Loaded 1144 placement summaries from ds_00925
#   [DEBUG] Loaded 378 placement summaries from ds_00926
#   [DEBUG] Loaded 284 placement summaries from ds_00927
#   [DEBUG] Loaded 1527 placement summaries from ds_00928
#   [DEBUG] Loaded 188 placement summaries from ds_00929
#   [DEBUG] Loaded 570 placement summaries from ds_00930
#   [DEBUG] Loaded 62 placement summaries from ds_00931
#   [DEBUG] Loaded 1721 placement summaries from ds_00932
#   [DEBUG] Loaded 2124 placement summaries from ds_00933
#   [DEBUG] Loaded 4056 placement summaries from ds_00934
#   [DEBUG] Loaded 1148 placement summaries from ds_00935
#   [DEBUG] Loaded 507 placement summaries from ds_00938
#   [DEBUG] Loaded 1594 placement summaries from ds_00939
#   [DEBUG] Loaded 1295 placement summaries from ds_00940
#   [DEBUG] Loaded 2125 placement summaries from ds_00942
#   [DEBUG] Loaded 1592 placement summaries from ds_00943
#   [DEBUG] Loaded 2302 placement summaries from ds_00944
#   [DEBUG] Loaded 58 placement summaries from ds_00945
#   [DEBUG] Loaded 505 placement summaries from ds_00948
#   [DEBUG] Loaded 1750 placement summaries from ds_00952
#   [DEBUG] Loaded 3194 placement summaries from ds_00953
#   [DEBUG] Loaded 2333 placement summaries from ds_00954
#   [DEBUG] Loaded 2813 placement summaries from ds_00958
#   [DEBUG] Loaded 2297 placement summaries from ds_00962
#   [DEBUG] Loaded 251 placement summaries from ds_00963
#   [DEBUG] Loaded 188 placement summaries from ds_00964
#   [DEBUG] Loaded 27 placement summaries from ds_00965
#   [DEBUG] Loaded 377 placement summaries from ds_00966
#   [DEBUG] Loaded 253 placement summaries from ds_00967
#   [DEBUG] Loaded 376 placement summaries from ds_00968
#   [DEBUG] Loaded 504 placement summaries from ds_00969
#   [DEBUG] Loaded 758 placement summaries from ds_00970
#   [DEBUG] Loaded 122 placement summaries from ds_00971
#   [DEBUG] Loaded 2294 placement summaries from ds_00972
#   [DEBUG] Loaded 250 placement summaries from ds_00973
#   [DEBUG] Loaded 189 placement summaries from ds_00974
#   [DEBUG] Loaded 1141 placement summaries from ds_00975
#   [DEBUG] Loaded 381 placement summaries from ds_00976
#   [DEBUG] Loaded 284 placement summaries from ds_00977
#   [DEBUG] Loaded 1531 placement summaries from ds_00978
#   [DEBUG] Loaded 187 placement summaries from ds_00979
#   [DEBUG] Loaded 569 placement summaries from ds_00980
#   [DEBUG] Loaded 57 placement summaries from ds_00981
#   [DEBUG] Loaded 1722 placement summaries from ds_00982
#   [DEBUG] Loaded 2375 placement summaries from ds_00983
#   [DEBUG] Loaded 5174 placement summaries from ds_00984
#   [DEBUG] Loaded 1147 placement summaries from ds_00985
#   [DEBUG] Loaded 377 placement summaries from ds_00986
#   [DEBUG] Loaded 282 placement summaries from ds_00987
#   [DEBUG] Loaded 1594 placement summaries from ds_00989
#   [DEBUG] Loaded 2718 placement summaries from ds_00992
#   [DEBUG] Loaded 1596 placement summaries from ds_00993
#   [DEBUG] Loaded 2552 placement summaries from ds_00994
#   [DEBUG] Loaded 1592 placement summaries from ds_00999
#   [DEBUG] Loaded 2297 placement summaries from ds_01002
#   [DEBUG] Loaded 1585 placement summaries from ds_01003
#   [DEBUG] Loaded 2555 placement summaries from ds_01004
#   [DEBUG] Loaded 1827 placement summaries from ds_01008
#   [DEBUG] Loaded 2297 placement summaries from ds_01012
#   [DEBUG] Loaded 2708 placement summaries from ds_01013
#   [DEBUG] Loaded 121 placement summaries from ds_01014
#   [DEBUG] Loaded 31 placement summaries from ds_01015
#   [DEBUG] Loaded 59 placement summaries from ds_01016
#   [DEBUG] Loaded 125 placement summaries from ds_01017
#   [DEBUG] Loaded 63 placement summaries from ds_01018
#   [DEBUG] Loaded 248 placement summaries from ds_01019
#   [DEBUG] Loaded 630 placement summaries from ds_01020
#   [DEBUG] Loaded 29 placement summaries from ds_01021
#   [DEBUG] Loaded 1277 placement summaries from ds_01022
#   [DEBUG] Loaded 126 placement summaries from ds_01023
#   [DEBUG] Loaded 126 placement summaries from ds_01024
#   [DEBUG] Loaded 30 placement summaries from ds_01025
#   [DEBUG] Loaded 61 placement summaries from ds_01026
#   [DEBUG] Loaded 122 placement summaries from ds_01027
#   [DEBUG] Loaded 1017 placement summaries from ds_01028
#   [DEBUG] Loaded 126 placement summaries from ds_01029
#   [DEBUG] Loaded 379 placement summaries from ds_01030
#   [DEBUG] Loaded 59 placement summaries from ds_01031
#   [DEBUG] Loaded 762 placement summaries from ds_01032
#   [DEBUG] Loaded 1015 placement summaries from ds_01033
#   [DEBUG] Loaded 1018 placement summaries from ds_01034
#   [DEBUG] Loaded 507 placement summaries from ds_01035
#   [DEBUG] Loaded 249 placement summaries from ds_01036
#   [DEBUG] Loaded 123 placement summaries from ds_01037
#   [DEBUG] Loaded 1018 placement summaries from ds_01038
#   [DEBUG] Loaded 119 placement summaries from ds_01039
#   [DEBUG] Loaded 1945 placement summaries from ds_01040
#   [DEBUG] Loaded 184 placement summaries from ds_01041
#   [DEBUG] Loaded 2649 placement summaries from ds_01042
#   [DEBUG] Loaded 396 placement summaries from ds_01043
#   [DEBUG] Loaded 235 placement summaries from ds_01044
#   [DEBUG] Loaded 67 placement summaries from ds_01045
#   [DEBUG] Loaded 378 placement summaries from ds_01046
#   [DEBUG] Loaded 555 placement summaries from ds_01047
#   [DEBUG] Loaded 572 placement summaries from ds_01048
#   [DEBUG] Loaded 1395 placement summaries from ds_01049
#   [DEBUG] Loaded 1942 placement summaries from ds_01050
#   [DEBUG] Loaded 188 placement summaries from ds_01051
#   [DEBUG] Loaded 2185 placement summaries from ds_01052
#   [DEBUG] Loaded 2704 placement summaries from ds_01053
#   [DEBUG] Loaded 1915 placement summaries from ds_01054
#   [DEBUG] Loaded 1795 placement summaries from ds_01055
#   [DEBUG] Loaded 378 placement summaries from ds_01056
#   [DEBUG] Loaded 641 placement summaries from ds_01057
#   [DEBUG] Loaded 1915 placement summaries from ds_01058
#   [DEBUG] Loaded 640 placement summaries from ds_01059
#   [DEBUG] Loaded 1464 placement summaries from ds_01060
#   [DEBUG] Loaded 76 placement summaries from ds_01061
#   [DEBUG] Loaded 2060 placement summaries from ds_01062
#   [DEBUG] Loaded 1913 placement summaries from ds_01063
#   [DEBUG] Loaded 1808 placement summaries from ds_01064
#   [DEBUG] Loaded 1795 placement summaries from ds_01065
#   [DEBUG] Loaded 376 placement summaries from ds_01066
#   [DEBUG] Loaded 187 placement summaries from ds_01067
#   [DEBUG] Loaded 189 placement summaries from ds_01068
#   [DEBUG] Loaded 282 placement summaries from ds_01069
#   [DEBUG] Loaded 193 placement summaries from ds_01070
#   [DEBUG] Loaded 60 placement summaries from ds_01071
#   [DEBUG] Loaded 1572 placement summaries from ds_01072
#   [DEBUG] Loaded 138 placement summaries from ds_01073
#   [DEBUG] Loaded 134 placement summaries from ds_01074
#   [DEBUG] Loaded 7 placement summaries from ds_01075
#   [DEBUG] Loaded 380 placement summaries from ds_01076
#   [DEBUG] Loaded 189 placement summaries from ds_01077
#   [DEBUG] Loaded 189 placement summaries from ds_01078
#   [DEBUG] Loaded 44 placement summaries from ds_01079
#   [DEBUG] Loaded 148 placement summaries from ds_01080
#   [DEBUG] Loaded 43 placement summaries from ds_01081
#   [DEBUG] Loaded 716 placement summaries from ds_01082
#   [DEBUG] Loaded 2050 placement summaries from ds_01083
#   [DEBUG] Loaded 3142 placement summaries from ds_01084
#   [DEBUG] Loaded 642 placement summaries from ds_01085
#   [DEBUG] Loaded 379 placement summaries from ds_01086
#   [DEBUG] Loaded 142 placement summaries from ds_01087
#   [DEBUG] Loaded 1146 placement summaries from ds_01088
#   [DEBUG] Loaded 45 placement summaries from ds_01089
#   [DEBUG] Loaded 145 placement summaries from ds_01090
#   [DEBUG] Loaded 45 placement summaries from ds_01091
#   [DEBUG] Loaded 2857 placement summaries from ds_01092
#   [DEBUG] Loaded 2297 placement summaries from ds_01093
#   [DEBUG] Loaded 2722 placement summaries from ds_01094
#   [DEBUG] Loaded 251 placement summaries from ds_01095
#   [DEBUG] Loaded 2552 placement summaries from ds_01096
#   [DEBUG] Loaded 3827 placement summaries from ds_01097
#   [DEBUG] Loaded 1272 placement summaries from ds_01098
#   [DEBUG] Loaded 2150 placement summaries from ds_01099
#   [DEBUG] Loaded 3023 placement summaries from ds_01100
#   [DEBUG] Loaded 504 placement summaries from ds_01101
#   [DEBUG] Loaded 2811 placement summaries from ds_01102
#   [DEBUG] Loaded 2296 placement summaries from ds_01103
#   [DEBUG] Loaded 2586 placement summaries from ds_01104
#   [DEBUG] Loaded 2316 placement summaries from ds_01105
#   [DEBUG] Loaded 3744 placement summaries from ds_01106
#   [DEBUG] Loaded 1573 placement summaries from ds_01107
#   [DEBUG] Loaded 1884 placement summaries from ds_01108
#   [DEBUG] Loaded 1272 placement summaries from ds_01109
#   [DEBUG] Loaded 1659 placement summaries from ds_01110
#   [DEBUG] Loaded 1528 placement summaries from ds_01111
#   [DEBUG] Loaded 3576 placement summaries from ds_01112
#   [DEBUG] Loaded 1913 placement summaries from ds_01113
#   [DEBUG] Loaded 1603 placement summaries from ds_01114
#   [DEBUG] Loaded 3131 placement summaries from ds_01115
#   [DEBUG] Loaded 2888 placement summaries from ds_01116
#   [DEBUG] Loaded 2169 placement summaries from ds_01117
#   [DEBUG] Loaded 32 placement summaries from ds_01118
#   [DEBUG] Loaded 60 placement summaries from ds_01119
#   [DEBUG] Loaded 375 placement summaries from ds_01120
#   [DEBUG] Loaded 8 placement summaries from ds_01121
#   [DEBUG] Loaded 188 placement summaries from ds_01122
#   [DEBUG] Loaded 27 placement summaries from ds_01123
#   [DEBUG] Loaded 9 placement summaries from ds_01124
#   [DEBUG] Loaded 7 placement summaries from ds_01125
#   [DEBUG] Loaded 11 placement summaries from ds_01126
#   [DEBUG] Loaded 14 placement summaries from ds_01127
#   [DEBUG] Loaded 31 placement summaries from ds_01128
#   [DEBUG] Loaded 60 placement summaries from ds_01129
#   [DEBUG] Loaded 380 placement summaries from ds_01130
#   [DEBUG] Loaded 3 placement summaries from ds_01131
#   [DEBUG] Loaded 264 placement summaries from ds_01132
#   [DEBUG] Loaded 444 placement summaries from ds_01133
#   [DEBUG] Loaded 265 placement summaries from ds_01134
#   [DEBUG] Loaded 142 placement summaries from ds_01135
#   [DEBUG] Loaded 10 placement summaries from ds_01136
#   [DEBUG] Loaded 25 placement summaries from ds_01137
#   [DEBUG] Loaded 94 placement summaries from ds_01138
#   [DEBUG] Loaded 48 placement summaries from ds_01139
#   [DEBUG] Loaded 296 placement summaries from ds_01140
#   [DEBUG] Loaded 2 placement summaries from ds_01141
#   [DEBUG] Loaded 266 placement summaries from ds_01142
#   [DEBUG] Loaded 445 placement summaries from ds_01143
#   [DEBUG] Loaded 4 placement summaries from ds_01144
#   [DEBUG] Loaded 10 placement summaries from ds_01146
#   [DEBUG] Loaded 3 placement summaries from ds_01147
#   [DEBUG] Loaded 15 placement summaries from ds_01149
#   [DEBUG] Loaded 70 placement summaries from ds_01152
#   [DEBUG] Loaded 4 placement summaries from ds_01153
#   [DEBUG] Loaded 3 placement summaries from ds_01154
#   [DEBUG] Loaded 10 placement summaries from ds_01156
#   [DEBUG] Loaded 7 placement summaries from ds_01157
#   [DEBUG] Loaded 21 placement summaries from ds_01158
#   [DEBUG] Loaded 3 placement summaries from ds_01159
#   [DEBUG] Loaded 8 placement summaries from ds_01160
#   [DEBUG] No placement_summary_*.json files found in ds_01161/placements/
#   [DEBUG] Loaded 51 placement summaries from ds_01162
#   [DEBUG] Loaded 157 placement summaries from ds_01163
#   [DEBUG] Loaded 155 placement summaries from ds_01164
#   [DEBUG] Loaded 6 placement summaries from ds_01165
#   [DEBUG] Loaded 9 placement summaries from ds_01166
#   [DEBUG] Loaded 8 placement summaries from ds_01167
#   [DEBUG] Loaded 23 placement summaries from ds_01168
#   [DEBUG] Loaded 5 placement summaries from ds_01169
#   [DEBUG] Loaded 1990 placement summaries from ds_01170
#   [DEBUG] Loaded 1703 placement summaries from ds_01171
#   [DEBUG] Loaded 2424 placement summaries from ds_01179
#   [DEBUG] Loaded 1570 placement summaries from ds_01180
#   [DEBUG] Loaded 1939 placement summaries from ds_01181
#   [DEBUG] Loaded 1707 placement summaries from ds_01183
#   [DEBUG] Loaded 1449 placement summaries from ds_01184
#   [DEBUG] Loaded 3499 placement summaries from ds_01185
#   [DEBUG] Loaded 3819 placement summaries from ds_01186
#   [DEBUG] Loaded 2304 placement summaries from ds_01187
#   [DEBUG] Loaded 2690 placement summaries from ds_01188
#   [DEBUG] Loaded 2109 placement summaries from ds_01189
#   [DEBUG] Loaded 2288 placement summaries from ds_01190
#   [DEBUG] Loaded 3693 placement summaries from ds_01191
#   [DEBUG] Loaded 2604 placement summaries from ds_01192
#   [DEBUG] Loaded 1938 placement summaries from ds_01193
#   [DEBUG] Loaded 1451 placement summaries from ds_01194
#   [DEBUG] Loaded 1674 placement summaries from ds_01195
#   [DEBUG] Loaded 2081 placement summaries from ds_01196
#   [DEBUG] Loaded 2227 placement summaries from ds_01197
#   [DEBUG] Loaded 2213 placement summaries from ds_01198
#   [DEBUG] Loaded 1975 placement summaries from ds_01199
#   [DEBUG] Loaded 2555 placement summaries from ds_01200
#   [DEBUG] Loaded 1616 placement summaries from ds_01201
#   [DEBUG] Loaded 1808 placement summaries from ds_01202
#   [DEBUG] Loaded 1344 placement summaries from ds_01203
#   [DEBUG] Loaded 1210 placement summaries from ds_01204
#   [DEBUG] Loaded 670 placement summaries from ds_01205
#   [DEBUG] Loaded 1887 placement summaries from ds_01206
#   [DEBUG] Loaded 2766 placement summaries from ds_01207
#   [DEBUG] Loaded 2481 placement summaries from ds_01208
#   [DEBUG] Loaded 4848 placement summaries from ds_01209
#   [DEBUG] Loaded 2986 placement summaries from ds_01210
#   [DEBUG] Loaded 1914 placement summaries from ds_01211
#   [DEBUG] Loaded 3172 placement summaries from ds_01212
#   [DEBUG] Loaded 2421 placement summaries from ds_01213
#   [DEBUG] Loaded 1986 placement summaries from ds_01214
#   [DEBUG] Loaded 3594 placement summaries from ds_01215
#   [DEBUG] Loaded 2125 placement summaries from ds_01216
#   [DEBUG] Loaded 1660 placement summaries from ds_01217
#   [DEBUG] Loaded 4205 placement summaries from ds_01218
#   [DEBUG] Loaded 2349 placement summaries from ds_01219
#   [DEBUG] Loaded 1616 placement summaries from ds_01220
#   [DEBUG] Loaded 1586 placement summaries from ds_01221
#   [DEBUG] Loaded 212 placement summaries from ds_01222
#   [DEBUG] Loaded 15 placement summaries from ds_01223
#   [DEBUG] Loaded 6 placement summaries from ds_01224
#   [DEBUG] Loaded 7 placement summaries from ds_01225
#   [DEBUG] Loaded 11 placement summaries from ds_01226
#   [DEBUG] Loaded 21 placement summaries from ds_01227
#   [DEBUG] Loaded 33 placement summaries from ds_01228
#   [DEBUG] Loaded 93 placement summaries from ds_01229
#   [DEBUG] Loaded 209 placement summaries from ds_01230
#   [DEBUG] Loaded 9 placement summaries from ds_01231
#   [DEBUG] Loaded 212 placement summaries from ds_01232
#   [DEBUG] Loaded 13 placement summaries from ds_01233
#   [DEBUG] Loaded 8 placement summaries from ds_01234
#   [DEBUG] Loaded 185 placement summaries from ds_01235
#   [DEBUG] Loaded 51 placement summaries from ds_01236
#   [DEBUG] Loaded 91 placement summaries from ds_01237
#   [DEBUG] Loaded 210 placement summaries from ds_01238
#   [DEBUG] Loaded 571 placement summaries from ds_01239
#   [DEBUG] Loaded 570 placement summaries from ds_01240
#   [DEBUG] Loaded 31 placement summaries from ds_01241
#   [DEBUG] Loaded 286 placement summaries from ds_01242
#   [DEBUG] Loaded 189 placement summaries from ds_01243
#   [DEBUG] Loaded 90 placement summaries from ds_01244
#   [DEBUG] Loaded 188 placement summaries from ds_01245
#   [DEBUG] Loaded 49 placement summaries from ds_01246
#   [DEBUG] Loaded 92 placement summaries from ds_01247
#   [DEBUG] Loaded 1600 placement summaries from ds_01249
#   [DEBUG] Loaded 3012 placement summaries from ds_01250
#   [DEBUG] Loaded 963 placement summaries from ds_01251
#   [DEBUG] Loaded 1735 placement summaries from ds_01259
#   [DEBUG] Loaded 2468 placement summaries from ds_01260
#   [DEBUG] Loaded 2322 placement summaries from ds_01261
#   [DEBUG] Loaded 1513 placement summaries from ds_01262
#   [DEBUG] Loaded 858 placement summaries from ds_01263
#   [DEBUG] Loaded 967 placement summaries from ds_01264
#   [DEBUG] Loaded 2906 placement summaries from ds_01265
#   [DEBUG] Loaded 3250 placement summaries from ds_01266
#   [DEBUG] Loaded 2902 placement summaries from ds_01267
#   [DEBUG] Loaded 3354 placement summaries from ds_01268
#   [DEBUG] Loaded 2438 placement summaries from ds_01269
#   [DEBUG] Loaded 1895 placement summaries from ds_01270
#   [DEBUG] Loaded 3250 placement summaries from ds_01271
#   [DEBUG] Loaded 2395 placement summaries from ds_01272
#   [DEBUG] Loaded 860 placement summaries from ds_01273
#   [DEBUG] Loaded 2422 placement summaries from ds_01279
#   [DEBUG] Loaded 2062 placement summaries from ds_01289
#   [DEBUG] Loaded 2349 placement summaries from ds_01299
#   [DEBUG] Loaded 1906 placement summaries from ds_01300
#   [DEBUG] Loaded 251 placement summaries from ds_01301
#   [DEBUG] Loaded 4311 placement summaries from ds_01302
#   [DEBUG] Loaded 252 placement summaries from ds_01303
#   [DEBUG] Loaded 190 placement summaries from ds_01304
#   [DEBUG] Loaded 125 placement summaries from ds_01305
#   [DEBUG] Loaded 376 placement summaries from ds_01306
#   [DEBUG] Loaded 569 placement summaries from ds_01307
# ...
#   [DEBUG] Loaded 1540 placement summaries from ds_02522
#   [DEBUG] Loaded 2244 placement summaries from ds_02523
#   [DEBUG] Loaded 1826 placement summaries from ds_02524
#   [DEBUG] Loaded 2108 placement summaries from ds_02525
#   [DEBUG] Loaded 3037 placement summaries from ds_02526
#   [DEBUG] Loaded 4057 placement summaries from ds_02527
#   [DEBUG] Loaded 1526 placement summaries from ds_02528
#   [DEBUG] Loaded 2230 placement summaries from ds_02529
#   [DEBUG] Loaded 1527 placement summaries from ds_02530
#   [DEBUG] Loaded 1630 placement summaries from ds_02531
#   [DEBUG] Loaded 2542 placement summaries from ds_02532
#   [DEBUG] Loaded 2541 placement summaries from ds_02533
#   [DEBUG] Loaded 2040 placement summaries from ds_02534
#   [DEBUG] Loaded 2784 placement summaries from ds_02538
#   [DEBUG] Loaded 1959 placement summaries from ds_02542
#   [DEBUG] Loaded 1973 placement summaries from ds_02543
#   [DEBUG] Loaded 1745 placement summaries from ds_02544
#   [DEBUG] Loaded 2041 placement summaries from ds_02548
#   [DEBUG] Loaded 3888 placement summaries from ds_02549
#   [DEBUG] Loaded 3037 placement summaries from ds_02550
#   [DEBUG] Loaded 2353 placement summaries from ds_02551
#   [DEBUG] Loaded 4459 placement summaries from ds_02552
#   [DEBUG] Loaded 1569 placement summaries from ds_02553
#   [DEBUG] Loaded 1278 placement summaries from ds_02554
#   [DEBUG] Loaded 2441 placement summaries from ds_02555
#   [DEBUG] Loaded 3206 placement summaries from ds_02556
#   [DEBUG] Loaded 1967 placement summaries from ds_02557
#   [DEBUG] Loaded 1988 placement summaries from ds_02558
#   [DEBUG] Loaded 5717 placement summaries from ds_02559
#   [DEBUG] Loaded 3530 placement summaries from ds_02560
#   [DEBUG] Loaded 2874 placement summaries from ds_02563
#   [DEBUG] Loaded 2107 placement summaries from ds_02573
#   [DEBUG] Loaded 90 placement summaries from ds_02574
#   [DEBUG] Loaded 858 placement summaries from ds_02575
#   [DEBUG] Loaded 761 placement summaries from ds_02576
#   [DEBUG] Loaded 2071 placement summaries from ds_02577
#   [DEBUG] Loaded 375 placement summaries from ds_02578
#   [DEBUG] Loaded 1719 placement summaries from ds_02579
#   [DEBUG] Loaded 2365 placement summaries from ds_02580
#   [DEBUG] Loaded 2947 placement summaries from ds_02581
#   [DEBUG] Loaded 1431 placement summaries from ds_02582
#   [DEBUG] Loaded 569 placement summaries from ds_02583
#   [DEBUG] Loaded 91 placement summaries from ds_02584
#   [DEBUG] Loaded 860 placement summaries from ds_02585
#   [DEBUG] Loaded 760 placement summaries from ds_02586
#   [DEBUG] Loaded 1720 placement summaries from ds_02593
#   [DEBUG] Loaded 2859 placement summaries from ds_02600
#   [DEBUG] Loaded 1646 placement summaries from ds_02601
#   [DEBUG] Loaded 4324 placement summaries from ds_02602
#   [DEBUG] Loaded 2914 placement summaries from ds_02603
#   [DEBUG] Loaded 2294 placement summaries from ds_02604
#   [DEBUG] Loaded 2376 placement summaries from ds_02605
#   [DEBUG] Loaded 2615 placement summaries from ds_02606
#   [DEBUG] Loaded 2363 placement summaries from ds_02607
#   [DEBUG] Loaded 1788 placement summaries from ds_02608
#   [DEBUG] Loaded 2573 placement summaries from ds_02609
#   [DEBUG] Loaded 1915 placement summaries from ds_02610
#   [DEBUG] Loaded 3962 placement summaries from ds_02611
#   [DEBUG] Loaded 2650 placement summaries from ds_02612
#   [DEBUG] Loaded 1898 placement summaries from ds_02613
#   [DEBUG] Loaded 1716 placement summaries from ds_02614
#   [DEBUG] Loaded 2482 placement summaries from ds_02618
#   [DEBUG] Loaded 2677 placement summaries from ds_02622
#   [DEBUG] Loaded 2351 placement summaries from ds_02623
#   [DEBUG] Loaded 2378 placement summaries from ds_02624
#   [DEBUG] Loaded 2815 placement summaries from ds_02626
#   [DEBUG] Loaded 2681 placement summaries from ds_02627
#   [DEBUG] Loaded 1272 placement summaries from ds_02628
#   [DEBUG] Loaded 1871 placement summaries from ds_02629
#   [DEBUG] Loaded 3425 placement summaries from ds_02630
#   [DEBUG] Loaded 3563 placement summaries from ds_02631
#   [DEBUG] Loaded 1841 placement summaries from ds_02632
#   [DEBUG] Loaded 2198 placement summaries from ds_02633
#   [DEBUG] Loaded 1784 placement summaries from ds_02634
#   [DEBUG] Loaded 2394 placement summaries from ds_02635
#   [DEBUG] Loaded 1917 placement summaries from ds_02636
#   [DEBUG] Loaded 3456 placement summaries from ds_02637
#   [DEBUG] Loaded 1273 placement summaries from ds_02638
#   [DEBUG] Loaded 1539 placement summaries from ds_02642
#   [DEBUG] Loaded 1780 placement summaries from ds_02643
#   [DEBUG] Loaded 4968 placement summaries from ds_02644
#   [DEBUG] Loaded 1780 placement summaries from ds_02648
#   [DEBUG] Loaded 1631 placement summaries from ds_02652
#   [DEBUG] Loaded 3535 placement summaries from ds_02653
#   [DEBUG] Loaded 2304 placement summaries from ds_02654
#   [DEBUG] Loaded 1899 placement summaries from ds_02655
#   [DEBUG] Loaded 3412 placement summaries from ds_02656
#   [DEBUG] Loaded 3711 placement summaries from ds_02657
#   [DEBUG] Loaded 2020 placement summaries from ds_02658
#   [DEBUG] Loaded 1571 placement summaries from ds_02659
#   [DEBUG] Loaded 2019 placement summaries from ds_02660
#   [DEBUG] Loaded 2767 placement summaries from ds_02661
#   [DEBUG] Loaded 2153 placement summaries from ds_02662
#   [DEBUG] Loaded 2750 placement summaries from ds_02663
#   [DEBUG] Loaded 1828 placement summaries from ds_02664
#   [DEBUG] Loaded 3757 placement summaries from ds_02668
#   [DEBUG] Loaded 4493 placement summaries from ds_02672
#   [DEBUG] Loaded 2109 placement summaries from ds_02673
#   [DEBUG] Loaded 2437 placement summaries from ds_02674
#   [DEBUG] Loaded 79 placement summaries from ds_02678
#   [DEBUG] Loaded 875 placement summaries from ds_02679
#   [DEBUG] Loaded 3144 placement summaries from ds_02680
#   [DEBUG] Loaded 716 placement summaries from ds_02681
#   [DEBUG] Loaded 416 placement summaries from ds_02682
#   [DEBUG] Loaded 284 placement summaries from ds_02683
#   [DEBUG] Loaded 94 placement summaries from ds_02684
#   [DEBUG] Loaded 293 placement summaries from ds_02685
#   [DEBUG] Loaded 93 placement summaries from ds_02686
#   [DEBUG] Loaded 499 placement summaries from ds_02687
#   [DEBUG] Loaded 77 placement summaries from ds_02688
#   [DEBUG] Loaded 877 placement summaries from ds_02689
#   [DEBUG] Loaded 2859 placement summaries from ds_02690
#   [DEBUG] Loaded 551 placement summaries from ds_02692
#   [DEBUG] Loaded 1195 placement summaries from ds_02693
#   [DEBUG] Loaded 313 placement summaries from ds_02694
#   [DEBUG] Loaded 172 placement summaries from ds_02698
#   [DEBUG] Loaded 553 placement summaries from ds_02702
#   [DEBUG] Loaded 1193 placement summaries from ds_02703
#   [DEBUG] Loaded 60 placement summaries from ds_02704
#   [DEBUG] Loaded 41 placement summaries from ds_02705
#   [DEBUG] Loaded 94 placement summaries from ds_02706
#   [DEBUG] Loaded 353 placement summaries from ds_02707
#   [DEBUG] Loaded 27 placement summaries from ds_02708
#   [DEBUG] Loaded 444 placement summaries from ds_02709
#   [DEBUG] Loaded 355 placement summaries from ds_02710
#   [DEBUG] Loaded 284 placement summaries from ds_02711
#   [DEBUG] Loaded 170 placement summaries from ds_02712
#   [DEBUG] Loaded 125 placement summaries from ds_02713
#   [DEBUG] Loaded 62 placement summaries from ds_02714
#   [DEBUG] Loaded 47 placement summaries from ds_02715
#   [DEBUG] Loaded 90 placement summaries from ds_02716
#   [DEBUG] Loaded 67 placement summaries from ds_02718
#   [DEBUG] Loaded 233 placement summaries from ds_02722
#   [DEBUG] Loaded 426 placement summaries from ds_02723
#   [DEBUG] Loaded 187 placement summaries from ds_02724
#   [DEBUG] Loaded 66 placement summaries from ds_02728
#   [DEBUG] Loaded 4173 placement summaries from ds_02730
#   [DEBUG] Loaded 2635 placement summaries from ds_02731
#   [DEBUG] Loaded 4671 placement summaries from ds_02732
#   [DEBUG] Loaded 3096 placement summaries from ds_02733
#   [DEBUG] Loaded 2901 placement summaries from ds_02734
#   [DEBUG] Loaded 2216 placement summaries from ds_02735
#   [DEBUG] Loaded 2048 placement summaries from ds_02736
#   [DEBUG] Loaded 3231 placement summaries from ds_02737
#   [DEBUG] Loaded 3038 placement summaries from ds_02738
#   [DEBUG] Loaded 3636 placement summaries from ds_02739
#   [DEBUG] Loaded 2676 placement summaries from ds_02740
#   [DEBUG] Loaded 3279 placement summaries from ds_02741
#   [DEBUG] Loaded 3293 placement summaries from ds_02742
#   [DEBUG] Loaded 1552 placement summaries from ds_02743
#   [DEBUG] Loaded 3201 placement summaries from ds_02744
#   [DEBUG] Loaded 1692 placement summaries from ds_02745
#   [DEBUG] Loaded 5178 placement summaries from ds_02746
#   [DEBUG] Loaded 3519 placement summaries from ds_02747
#   [DEBUG] Loaded 4072 placement summaries from ds_02748
#   [DEBUG] Loaded 2288 placement summaries from ds_02749
#   [DEBUG] Loaded 2918 placement summaries from ds_02750
#   [DEBUG] Loaded 3876 placement summaries from ds_02751
#   [DEBUG] Loaded 3173 placement summaries from ds_02752
#   [DEBUG] Loaded 2346 placement summaries from ds_02753
#   [DEBUG] Loaded 2363 placement summaries from ds_02754
#   [DEBUG] Loaded 2215 placement summaries from ds_02755
#   [DEBUG] Loaded 3324 placement summaries from ds_02756
#   [DEBUG] Loaded 1718 placement summaries from ds_02757
#   [DEBUG] Loaded 1568 placement summaries from ds_02758
#   [DEBUG] Loaded 1915 placement summaries from ds_02759
#   [DEBUG] Loaded 2305 placement summaries from ds_02760
#   [DEBUG] Loaded 2017 placement summaries from ds_02761
#   [DEBUG] Loaded 3893 placement summaries from ds_02762
#   [DEBUG] Loaded 2842 placement summaries from ds_02763
#   [DEBUG] Loaded 1809 placement summaries from ds_02764
#   [DEBUG] Loaded 2559 placement summaries from ds_02765
#   [DEBUG] Loaded 6032 placement summaries from ds_02766
#   [DEBUG] Loaded 2798 placement summaries from ds_02767
#   [DEBUG] Loaded 2798 placement summaries from ds_02768
#   [DEBUG] Loaded 3199 placement summaries from ds_02769
#   [DEBUG] Loaded 1808 placement summaries from ds_02770
#   [DEBUG] Loaded 1902 placement summaries from ds_02771
#   [DEBUG] Loaded 3202 placement summaries from ds_02772
#   [DEBUG] Loaded 2946 placement summaries from ds_02773
#   [DEBUG] Loaded 1853 placement summaries from ds_02774
#   [DEBUG] Loaded 2589 placement summaries from ds_02775
#   [DEBUG] Loaded 1601 placement summaries from ds_02776
#   [DEBUG] Loaded 4038 placement summaries from ds_02777
#   [DEBUG] Loaded 2376 placement summaries from ds_02778
#   [DEBUG] Loaded 2412 placement summaries from ds_02779
#   [DEBUG] Loaded 2871 placement summaries from ds_02780
#   [DEBUG] Loaded 1884 placement summaries from ds_02781
#   [DEBUG] Loaded 355 placement summaries from ds_02782
#   [DEBUG] Loaded 1992 placement summaries from ds_02783
#   [DEBUG] Loaded 954 placement summaries from ds_02784
#   [DEBUG] Loaded 713 placement summaries from ds_02785
#   [DEBUG] Loaded 592 placement summaries from ds_02786
#   [DEBUG] Loaded 235 placement summaries from ds_02787
#   [DEBUG] Loaded 897 placement summaries from ds_02788
#   [DEBUG] Loaded 893 placement summaries from ds_02789
#   [DEBUG] Loaded 2243 placement summaries from ds_02790
#   [DEBUG] Loaded 293 placement summaries from ds_02791
#   [DEBUG] Loaded 354 placement summaries from ds_02792
#   [DEBUG] Loaded 1778 placement summaries from ds_02793
#   [DEBUG] Loaded 955 placement summaries from ds_02794
#   [DEBUG] Loaded 793 placement summaries from ds_02795
#   [DEBUG] Loaded 182 placement summaries from ds_02796
#   [DEBUG] Loaded 248 placement summaries from ds_02797
#   [DEBUG] Loaded 711 placement summaries from ds_02798
#   [DEBUG] Loaded 379 placement summaries from ds_02799
#   [DEBUG] Loaded 791 placement summaries from ds_02800
#   [DEBUG] Loaded 77 placement summaries from ds_02801
#   [DEBUG] Loaded 1274 placement summaries from ds_02802
#   [DEBUG] Loaded 760 placement summaries from ds_02803
#   [DEBUG] Loaded 1017 placement summaries from ds_02804
#   [DEBUG] Loaded 790 placement summaries from ds_02805
#   [DEBUG] Loaded 186 placement summaries from ds_02806
#   [DEBUG] Loaded 253 placement summaries from ds_02807
#   [DEBUG] Loaded 1540 placement summaries from ds_02808
#   [DEBUG] Loaded 2272 placement summaries from ds_02809
#   [DEBUG] Loaded 3951 placement summaries from ds_02810
#   [DEBUG] Loaded 2799 placement summaries from ds_02811
#   [DEBUG] Loaded 2709 placement summaries from ds_02812
#   [DEBUG] Loaded 4113 placement summaries from ds_02813
#   [DEBUG] Loaded 4324 placement summaries from ds_02814
#   [DEBUG] Loaded 3094 placement summaries from ds_02815
#   [DEBUG] Loaded 1676 placement summaries from ds_02816
#   [DEBUG] Loaded 2843 placement summaries from ds_02817
#   [DEBUG] Loaded 3205 placement summaries from ds_02818
#   [DEBUG] Loaded 2244 placement summaries from ds_02819
#   [DEBUG] Loaded 2150 placement summaries from ds_02820
#   [DEBUG] Loaded 2908 placement summaries from ds_02821
#   [DEBUG] Loaded 1781 placement summaries from ds_02822
#   [DEBUG] Loaded 3336 placement summaries from ds_02823
#   [DEBUG] Loaded 3866 placement summaries from ds_02824
#   [DEBUG] Loaded 2197 placement summaries from ds_02825
#   [DEBUG] Loaded 2873 placement summaries from ds_02826
#   [DEBUG] Loaded 2810 placement summaries from ds_02827
#   [DEBUG] Loaded 1567 placement summaries from ds_02828
#   [DEBUG] Loaded 1719 placement summaries from ds_02829
#   [DEBUG] Loaded 3769 placement summaries from ds_02830
#   [DEBUG] Loaded 2425 placement summaries from ds_02831
#   [DEBUG] Loaded 3515 placement summaries from ds_02832
#   [DEBUG] Loaded 3109 placement summaries from ds_02833
#   [DEBUG] Loaded 1613 placement summaries from ds_02834
#   [DEBUG] Loaded 2016 placement summaries from ds_02836
#   [DEBUG] Loaded 3086 placement summaries from ds_02837
#   [DEBUG] Loaded 4357 placement summaries from ds_02839
#   [DEBUG] Loaded 3502 placement summaries from ds_02842
#   [DEBUG] Loaded 4013 placement summaries from ds_02843
#   [DEBUG] Loaded 2320 placement summaries from ds_02844
#   [DEBUG] Loaded 2244 placement summaries from ds_02846
#   [DEBUG] Loaded 2678 placement summaries from ds_02848
#   [DEBUG] Loaded 3173 placement summaries from ds_02851
#   [DEBUG] Loaded 2875 placement summaries from ds_02855
#   [DEBUG] Loaded 3230 placement summaries from ds_02856
#   [DEBUG] Loaded 2857 placement summaries from ds_02858
#   [DEBUG] Loaded 4264 placement summaries from ds_02860
#   [DEBUG] Loaded 3966 placement summaries from ds_02861
#   [DEBUG] Loaded 3279 placement summaries from ds_02862
#   [DEBUG] Loaded 2183 placement summaries from ds_02863
#   [DEBUG] Loaded 1886 placement summaries from ds_02864
#   [DEBUG] Loaded 1734 placement summaries from ds_02865
#   [DEBUG] Loaded 2828 placement summaries from ds_02866
#   [DEBUG] Loaded 1690 placement summaries from ds_02867
#   [DEBUG] Loaded 2305 placement summaries from ds_02868
#   [DEBUG] Loaded 4687 placement summaries from ds_02869
#   [DEBUG] Loaded 1539 placement summaries from ds_02870
#   [DEBUG] Loaded 1869 placement summaries from ds_02871
#   [DEBUG] Loaded 2244 placement summaries from ds_02872
#   [DEBUG] Loaded 2601 placement summaries from ds_02873
#   [DEBUG] Loaded 2110 placement summaries from ds_02874
#   [DEBUG] Loaded 2867 placement summaries from ds_02875
#   [DEBUG] Loaded 2828 placement summaries from ds_02876
#   [DEBUG] Loaded 4744 placement summaries from ds_02877
#   [DEBUG] Loaded 3023 placement summaries from ds_02878
#   [DEBUG] Loaded 1915 placement summaries from ds_02879
#   [DEBUG] Loaded 3051 placement summaries from ds_02880
#   [DEBUG] Loaded 2040 placement summaries from ds_02881
#   [DEBUG] Loaded 1931 placement summaries from ds_02882
#   [DEBUG] Loaded 2005 placement summaries from ds_02883
#   [DEBUG] Loaded 1855 placement summaries from ds_02884
#   [DEBUG] Loaded 1572 placement summaries from ds_02885
#   [DEBUG] Loaded 3025 placement summaries from ds_02886
#   [DEBUG] Loaded 2604 placement summaries from ds_02887
#   [DEBUG] Loaded 4056 placement summaries from ds_02888
#   [DEBUG] Loaded 1572 placement summaries from ds_02889
#   [DEBUG] Loaded 3954 placement summaries from ds_02890
#   [DEBUG] Loaded 3952 placement summaries from ds_02891
#   [DEBUG] Loaded 2817 placement summaries from ds_02892
#   [DEBUG] Loaded 1705 placement summaries from ds_02893

# %%
os.environ['WANDB_API_KEY'] = '85cccc04212d62b698dbc4549b87818a95850133'

wandb.init(
    project="scheduling-gnn-rtt-metrics",
    entity="nikolalukic167-tu-wien",
    config={
        "embedding_dim": EMBEDDING_DIM,
        "hidden_dim": HIDDEN_DIM,
        "lr": LEARNING_RATE,
        "epochs": EPOCHS,
        "device": DEVICE,
    }
)

# %%
# ========================================================================
# Initialize model
# ========================================================================
# Task features: 2 (task types) + 1 (source node ID) = 3
# Platform features: 5 (platform types) + 2 (replica flags) = 7 (old)
task_feature_dim = 3
platform_feature_dim = 7

model = TaskPlacementGNN(
    task_feature_dim=task_feature_dim,
    platform_feature_dim=platform_feature_dim,
    embedding_dim=EMBEDDING_DIM,
    hidden_dim=HIDDEN_DIM,
    num_layers=NUM_GIN_LAYERS
).to(DEVICE)

# Weight initialization for training stability
def init_weights(m):
    """Initialize weights using Xavier uniform and zeros for bias."""
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        nn.init.zeros_(m.bias)

model.apply(init_weights)

# optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print()

# ========================================================================
# Training loop
# ========================================================================
print("="*80)
print("TRAINING")
print("="*80)
print()

wandb.watch(model, log="gradients", log_freq=100)  # now that model exists

best_val_acc = 0

train_loader = DataLoader(train_graphs, batch_size=BATCH_SIZE, shuffle=True,  num_workers=4, pin_memory=True)
test_loader  = DataLoader(test_graphs,  batch_size=BATCH_SIZE, shuffle=False, num_workers=4, pin_memory=True)

for epoch in range(EPOCHS):
    # Train
    train_losses = train_epoch(model, train_loader, optimizer, DEVICE, epoch)
    
    # Evaluate
    val_metrics = evaluate(model, test_loader, DEVICE)
    
    # Wandb logging - all losses and metrics
    log_dict = {
        "epoch": epoch,
        "train/loss_ce": train_losses['ce'],
        "train/loss_expected_rtt": train_losses['expected_rtt'],
        "train/loss_soft_label": train_losses['soft_label'],
        "val/loss_ce": val_metrics['ce'],
        "val/loss_expected_rtt": val_metrics['expected_rtt'],
        "val/loss_soft_label": val_metrics['soft_label'],
        "val/acc": val_metrics['acc'],
        "lr": optimizer.param_groups[0]["lr"],
    }
    
    # Add RTT-based metrics if available
    if val_metrics.get('n_rtt_evaluations', 0) > 0:
        log_dict.update({
            "val/regret": val_metrics['regret'],
            "val/normalized_regret": val_metrics['normalized_regret'],
            "val/top1_acc": val_metrics['top1_acc'],
            "val/top3_acc": val_metrics['top3_acc'],
            "val/top5_acc": val_metrics['top5_acc'],
            "val/predicted_rtt": val_metrics['predicted_rtt'],
            "val/optimal_rtt": val_metrics['optimal_rtt'],
        })
    
    wandb.log(log_dict, step=epoch)
    
    if val_metrics['acc'] > best_val_acc:
        best_val_acc = val_metrics['acc']
        # Save best model
        torch.save(model.state_dict(), 'best_gnn_placement_model.pt')
    
    if epoch % 10 == 0 or epoch == EPOCHS - 1:
        print(f"Epoch {epoch:3d}/{EPOCHS} | "
              f"Train CE: {train_losses['ce']:.4f} | "
              f"Train ERTT: {train_losses['expected_rtt']:.4f} | "
              f"Train SL: {train_losses['soft_label']:.4f} | "
              f"Val CE: {val_metrics['ce']:.4f} | "
              f"Val ERTT: {val_metrics['expected_rtt']:.4f} | "
              f"Val SL: {val_metrics['soft_label']:.4f} | "
              f"Val Acc: {val_metrics['acc']*100:.2f}%", end="")
        
        # Print RTT metrics if available
        if val_metrics.get('n_rtt_evaluations', 0) > 0:
            print(f" | Regret: {val_metrics['regret']:.2f}s | "
                  f"Top1: {val_metrics['top1_acc']*100:.1f}% | "
                  f"Top3: {val_metrics['top3_acc']*100:.1f}% | "
                  f"Top5: {val_metrics['top5_acc']*100:.1f}% | "
                  f"Within5%: {val_metrics.get('within_5pct_acc', 0.0)*100:.1f}% | "
                  f"Within10%: {val_metrics.get('within_10pct_acc', 0.0)*100:.1f}%")
        else:
            print()

print()
print(f"Best validation accuracy: {best_val_acc*100:.2f}%")

# ========================================================================
# Final Evaluation
# ========================================================================
print()
print("="*80)
print("FINAL EVALUATION")
print("="*80)

# Load best model
model.load_state_dict(torch.load('best_gnn_placement_model.pt'))

train_loader_eval = DataLoader(train_graphs, batch_size=BATCH_SIZE, shuffle=False, num_workers=4, pin_memory=True)
test_loader_eval  = DataLoader(test_graphs,  batch_size=BATCH_SIZE, shuffle=False, num_workers=4, pin_memory=True)

train_metrics = evaluate(model, train_loader_eval, DEVICE)
test_metrics  = evaluate(model, test_loader_eval,  DEVICE)

# ========================================================================
# WANDB
# ========================================================================

# Log simple counts
wandb.log({
    "data/num_datasets_total": len(graphs),
    "data/num_train": len(train_graphs),
    "data/num_test":  len(test_graphs),
})

# Optionally: store the list of dataset IDs for traceability
wandb.summary["train_dataset_ids"] = train_ids
wandb.summary["test_dataset_ids"]  = test_ids

wandb.summary["best_val_acc"] = best_val_acc

artifact = wandb.Artifact("placement-gnn", type="model")
artifact.add_file("best_gnn_placement_model.pt")
# with open("splits.json","w") as f: json.dump({"train": train_ids, "test": test_ids}, f)
# artifact.add_file("splits.json")
wandb.log_artifact(artifact)

wandb.finish()

# ========================================================================
# local logging
# ========================================================================

print(f"\nTrain: CE={train_metrics['ce']:.4f}, ERTT={train_metrics['expected_rtt']:.4f}, SL={train_metrics['soft_label']:.4f}, Acc={train_metrics['acc']*100:.2f}%")
if train_metrics.get('n_rtt_evaluations', 0) > 0:
    print(f"       Regret: {train_metrics['regret']:.2f}s | Top1: {train_metrics['top1_acc']*100:.1f}% | Top3: {train_metrics['top3_acc']*100:.1f}% | Top5: {train_metrics['top5_acc']*100:.1f}% | Within5%: {train_metrics.get('within_5pct_acc',0.0)*100:.1f}% | Within10%: {train_metrics.get('within_10pct_acc',0.0)*100:.1f}%")
    print(f"       Predicted RTT: {train_metrics['predicted_rtt']:.2f}s | Optimal RTT: {train_metrics['optimal_rtt']:.2f}s")

print(f"Test:  CE={test_metrics['ce']:.4f}, ERTT={test_metrics['expected_rtt']:.4f}, SL={test_metrics['soft_label']:.4f}, Acc={test_metrics['acc']*100:.2f}%")
if test_metrics.get('n_rtt_evaluations', 0) > 0:
    print(f"       Regret: {test_metrics['regret']:.2f}s | Top1: {test_metrics['top1_acc']*100:.1f}% | Top3: {test_metrics['top3_acc']*100:.1f}% | Top5: {test_metrics['top5_acc']*100:.1f}% | Within5%: {test_metrics.get('within_5pct_acc',0.0)*100:.1f}% | Within10%: {test_metrics.get('within_10pct_acc',0.0)*100:.1f}%")
    print(f"       Predicted RTT: {test_metrics['predicted_rtt']:.2f}s | Optimal RTT: {test_metrics['optimal_rtt']:.2f}s")

print("\n" + "="*80)
print("TRAINING COMPLETE!")
print("="*80)
print(f"Model saved to: best_gnn_placement_model.pt")
print(f"Best validation accuracy: {best_val_acc*100:.2f}%")
